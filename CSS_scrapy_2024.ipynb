# %%
#to install scrapy package
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 819.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.2/254.2 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.6 MB/s eta 0:00:00
# ...

# %%
from scrapy import Selector

# %%
html = '''
<html>
  <body>
    <div class = "class-intro">
      <p>"Hello CSS"</p>
      <p>"Hello Python"</p>
    </div>
    <div class = "class-intro">
      <p>"Hello scrapy"</p>
      <p>"Hello sipder"</p>
    </div>
    <div class = "class-intro2">
      <p>"Hello TTC3213"</p>
    </div>
    <p id="p-example">
      Hello world!
      Try <a href="http://www.datacamp.com">DataCamp</a> today!
    </p>
  </body>
</html>
'''
sel = Selector (text = html)

# %%
#look forward one generation
sel.css('div> p').extract()
# Out:
# ['<p>"Hello CSS"</p>',
#  '<p>"Hello Python"</p>',
#  '<p>"Hello scrapy"</p>',
#  '<p>"Hello sipder"</p>',
#  '<p>"Hello TTC3213"</p>']

# %%
#choose specific element
sel.css('div > p:nth-of-type(2)').extract()
# Out:
# ['<p>"Hello Python"</p>', '<p>"Hello sipder"</p>']

# %%
#look forward to all chidren
sel.css(' p').extract()
# Out:
# ['<p>"Hello CSS"</p>',
#  '<p>"Hello Python"</p>',
#  '<p>"Hello scrapy"</p>',
#  '<p>"Hello sipder"</p>',
#  '<p>"Hello TTC3213"</p>',
#  '<p id="p-example">\n      Hello world!\n      Try <a href="http://www.datacamp.com">DataCamp</a> today!\n    </p>']

# %%
#choose paragraph element by id
sel.css('p#p-example').extract()
# Out:
# ['<p id="p-example">\n      Hello world!\n      Try <a href="http://www.datacamp.com">DataCamp</a> today!\n    </p>']

# %%
#extract text from element
sel.css('p#p-example::text').extract()
# Out:
# ['\n      Hello world!\n      Try ', ' today!\n    ']

# %%
sel.css('div.class-intro').extract()
# Out:
# ['<div class="class-intro">\n      <p>"Hello CSS"</p>\n      <p>"Hello Python"</p>\n    </div>',
#  '<div class="class-intro">\n      <p>"Hello scrapy"</p>\n      <p>"Hello sipder"</p>\n    </div>']

# %% [markdown]
# # **Exercise**

# %%
html_2 = '''
<html>
  <body>
    <div class="attMgy">
      <span>"Sambal Garing Chiang Rai 120g"</span>
    </div>
    <div class="flex_3A3c6">
      <div class="OitLRu">267</div>
      <div class="tuNfsN">ratings</div>
    </div>
    <div class="flex_210dTF">
      <div class="aca9MM">1.4k</div>
      <div class="INCrso">sold</div>
    </div>
  </body>
</html>
'''

sel2 = Selector(text=html_2)

# %%
sel2.css('div.OitLRu').extract()
# Out:
# ['<div class="OitLRu">267</div>']

# %%
sel2.css('div.OitLRu::text').extract()
# Out:
# ['267']

# %%
sel2.css('div.OitLRu::text').get()
# Out:
# '267'

# %%
sel2.css('div.aca9MM::text').extract()
# Out:
# ['1.4k']

# %% [markdown]
# GROUP: DS-4
#
# GROUP MEMBERS: IZZUL, AJRUL, ZUHDI, WAN
