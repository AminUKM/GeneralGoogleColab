# %% [markdown]
# This module is prepared for  SOCIAL MEDIA MINING MADE EASY: PYTHON TEXT ANALYTICS CRASH COURSE WORKSHOP, 25-26 September 2023.
#
# Author: Dr Lailatul Qadri Zakaria, Asian Language Processing Lab (ASLAN), Center For Artificial Intelligence Technology (CAIT), Faculty of Information Science and Technology (FTSM), Universiti Kebangsaan Malaysia (UKM).
#
# Email: lailatul.qadri@ukm.edu.my

# %% [markdown]
# #Tweety
# Previously, numerous Python libraries that did not utilise Twitter's API could be used for Twitter data scraping, however owing to changes in Twitter policy, most of the libraries are no longer usable.
#
# In this workshop, I will use **Tweepy** library to extract Twitter data. Tweepy is can be used to extract data such as get user info, get tweets, searching tweets based on keywords, get trends, get community and get community tweets.
#
# Let's go!
#
# Resource for Tweety documentation link: https://mahrtayyab.github.io/tweety_docs/#

# %% [markdown]
# ## Install required library

# %% [markdown]
# ### 1. We need to install tweety library using the following code:

# %%
# !pip install tweety-ns
# Out:
# Requirement already satisfied: tweety-ns in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from tweety-ns) (4.12.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from tweety-ns) (3.1.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from tweety-ns) (0.27.0)
# Requirement already satisfied: dateutils in /usr/local/lib/python3.10/dist-packages (from tweety-ns) (0.6.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->tweety-ns) (2.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateutils->tweety-ns) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateutils->tweety-ns) (2023.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->tweety-ns) (0.14.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->tweety-ns) (1.1.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->tweety-ns) (1.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateutils->tweety-ns) (1.16.0)

# %% [markdown]
# ### 2. Upgrade the library to the latest version:

# %%
# !pip install https://github.com/mahrtayyab/tweety/archive/main.zip --upgrade
# Out:
# Collecting https://github.com/mahrtayyab/tweety/archive/main.zip
#   Using cached https://github.com/mahrtayyab/tweety/archive/main.zip (98 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from tweety-ns==1.1.3) (4.12.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from tweety-ns==1.1.3) (3.1.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from tweety-ns==1.1.3) (0.27.0)
# Requirement already satisfied: dateutils in /usr/local/lib/python3.10/dist-packages (from tweety-ns==1.1.3) (0.6.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->tweety-ns==1.1.3) (2.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateutils->tweety-ns==1.1.3) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateutils->tweety-ns==1.1.3) (2023.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns==1.1.3) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns==1.1.3) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns==1.1.3) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns==1.1.3) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->tweety-ns==1.1.3) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->tweety-ns==1.1.3) (0.14.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->tweety-ns==1.1.3) (1.1.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->tweety-ns==1.1.3) (1.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateutils->tweety-ns==1.1.3) (1.16.0)

# %% [markdown]
# ## Tweety Functions
#
# **Note:** If you have a Twitter account, you may use your Twitter ID and password to access more Tweepy features. Otherwise, your Tweety access is restricted to the first two functions.
#
#
# **Basic Functions:**
#
# a.   Get User Info
#
# b.   Get User's Tweet (limited to 100 tweets)
#
# **Advance Functions:**
#
# a.   Get User Info (similar to basic function)
#
# b.   Get User's Tweet (more than 100 tweets)
#
# c.   Searching a keyword

# %%
from tweety import Twitter
app = Twitter("session")

# %% [markdown]
# ### 1. Basic Function (no sign-in required)
#
# #### a.  Get User info
# Lets try to search for a public figure in Twitter. In this example, I will search for our former prime minister - Tun Dr Mahathir Mohamad. You will need his twitter name to get his information: "chedetofficial".

# %%
user = app.get_user_info('chedetofficial')
print(user)
# Out:
# User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True)

# %% [markdown]
# Now, try to get other user information by changing the user name. You also can search for your user information.

# %%
user = app.get_user_info('Aremien1096206')
print(user)
# Out:
# User(id=1778704336094367744, username=Aremien1096206, name=Are_mien, verified=False)

# %% [markdown]
# #### b. Get tweets from the user (limited to 100 tweets)
# You now have the user information. Next, let's see if we can capture what they tweet. In this example, I would like to extract Tun M' tweets and save it into pandas.

# %%
# Importing pandas as pd
import pandas as pd

# %% [markdown]
# After running this code, you will receive raw tweet data from Tun M. It comprises a lot of information, like the Tweet id, author, username, and produced data. Observe the output:
# *   Without Twitter User ID and password, you only can access 100 tweet from the user.
# *   Tweet's date are random

# %%
all_tweets = app.get_tweets("chedetofficial")

tweet_text = [] # we want to store tweet's text
tweet_date = [] # we want to store tweet's date

for tweet in all_tweets:
      print(tweet)
      tweet_text.append(tweet.text)
      tweet_date.append(tweet.date)
# Out:
# Tweet(id=1232164352800645121, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-02-25 04:44:08+00:00)
# Tweet(id=994832602816278529, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-11 06:52:30+00:00)
# Tweet(id=994448161212018689, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-10 05:24:52+00:00)
# Tweet(id=1198088000359428096, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-11-23 03:56:53+00:00)
# Tweet(id=996903394223812614, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-17 00:01:05+00:00)
# Tweet(id=1714951451079049272, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2023-10-19 10:27:42+00:00)
# Tweet(id=1290817057915719680, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-08-05 01:09:03+00:00)
# Tweet(id=1148780847387967488, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-07-10 02:27:51+00:00)
# Tweet(id=1149690635294662656, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-07-12 14:43:02+00:00)
# Tweet(id=890386046361321473, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-07-27 01:39:10+00:00)
# Tweet(id=1595982249652281346, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2022-11-25 03:26:34+00:00)
# Tweet(id=1231826770036326400, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-02-24 06:22:42+00:00)
# Tweet(id=1167652883455545344, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-08-31 04:18:36+00:00)
# Tweet(id=880434769565294592, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-06-29 14:36:21+00:00)
# Tweet(id=939002203540373504, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-12-08 05:22:25+00:00)
# Tweet(id=1130738478277320704, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-05-21 07:33:55+00:00)
# Tweet(id=995923584257220609, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-14 07:07:40+00:00)
# Tweet(id=1711309964424458466, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2023-10-09 09:17:44+00:00)
# Tweet(id=1031466462081241089, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-08-20 09:02:22+00:00)
# Tweet(id=1393173341876359169, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2021-05-14 11:56:23+00:00)
# Tweet(id=908719675890057216, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-09-15 15:50:28+00:00)
# Tweet(id=904546721199300615, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-09-04 03:28:38+00:00)
# Tweet(id=1720820366661259648, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2023-11-04 15:08:41+00:00)
# Tweet(id=1264369629545107456, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-05-24 01:36:25+00:00)
# Tweet(id=998366315386568704, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-21 00:54:12+00:00)
# Tweet(id=994576019070771201, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-10 13:52:55+00:00)
# Tweet(id=990025361952944128, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-04-28 00:30:14+00:00)
# Tweet(id=1717100243664486537, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2023-10-25 08:46:14+00:00)
# Tweet(id=1518430468466954240, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2022-04-25 03:23:29+00:00)
# Tweet(id=1628981880677863425, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2023-02-24 04:55:20+00:00)
# Tweet(id=1291617559100317696, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-08-07 06:09:57+00:00)
# Tweet(id=920112343639400448, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-10-17 02:20:52+00:00)
# Tweet(id=1243842728032518144, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-03-28 10:09:50+00:00)
# Tweet(id=1281055206956916736, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-07-09 02:38:56+00:00)
# Tweet(id=976745594227113985, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-03-22 09:01:11+00:00)
# Tweet(id=1393000813409103874, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2021-05-14 00:30:49+00:00)
# Tweet(id=1719693207762866388, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2023-11-01 12:29:45+00:00)
# Tweet(id=1001104177638948865, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-28 14:13:30+00:00)
# Tweet(id=1171773819255545856, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-09-11 13:13:43+00:00)
# Tweet(id=1292040968837844993, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-08-08 10:12:26+00:00)
# Tweet(id=970457622477336576, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-03-05 00:35:02+00:00)
# Tweet(id=941288155629568001, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-12-14 12:45:59+00:00)
# Tweet(id=1331473787049558016, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-11-25 05:44:23+00:00)
# Tweet(id=907788450069278720, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-09-13 02:10:07+00:00)
# Tweet(id=1065245532384190465, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-11-21 14:08:20+00:00)
# Tweet(id=997332985421619200, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-18 04:28:07+00:00)
# Tweet(id=884694437355413504, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-07-11 08:42:45+00:00)
# Tweet(id=947387891298156546, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-12-31 08:44:09+00:00)
# Tweet(id=885113525273640961, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-07-12 12:28:03+00:00)
# Tweet(id=1266264960964808712, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-05-29 07:07:47+00:00)
# Tweet(id=938700397333528576, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-12-07 09:23:09+00:00)
# Tweet(id=1016638563163623424, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-07-10 11:01:36+00:00)
# Tweet(id=1282313505408835585, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-07-12 13:58:58+00:00)
# Tweet(id=1007268145004834817, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-06-14 14:26:54+00:00)
# Tweet(id=1109053999238574080, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-03-22 11:27:33+00:00)
# Tweet(id=999596772975460352, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-24 10:23:36+00:00)
# Tweet(id=903189051682938880, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-08-31 09:33:45+00:00)
# Tweet(id=1108778261100793859, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-03-21 17:11:52+00:00)
# Tweet(id=1233766104176058369, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-02-29 14:48:56+00:00)
# Tweet(id=1595274337430384640, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2022-11-23 04:33:35+00:00)
# Tweet(id=1231839117496815617, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-02-24 07:11:46+00:00)
# Tweet(id=940097260305620993, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-12-11 05:53:47+00:00)
# Tweet(id=1056816759523569664, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-10-29 07:55:24+00:00)
# Tweet(id=1109027167999086592, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-03-22 09:40:56+00:00)
# Tweet(id=1002192906050928640, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-31 14:19:43+00:00)
# Tweet(id=1150250512291254273, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-07-14 03:47:47+00:00)
# Tweet(id=982895160622170112, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-04-08 08:17:22+00:00)
# Tweet(id=1221708324753666055, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-01-27 08:15:37+00:00)
# Tweet(id=1127446320719884288, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-05-12 05:32:04+00:00)
# Tweet(id=996694526499549184, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-16 10:11:07+00:00)
# Tweet(id=1601136308751335424, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2022-12-09 08:46:58+00:00)
# Tweet(id=903120826228031488, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-08-31 05:02:38+00:00)
# Tweet(id=1108666435679801347, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-03-21 09:47:30+00:00)
# Tweet(id=999228780852924417, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-23 10:01:20+00:00)
# Tweet(id=893816142782844932, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-08-05 12:49:09+00:00)
# Tweet(id=995577665317818368, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-13 08:13:07+00:00)
# Tweet(id=927418413001031682, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-11-06 06:12:34+00:00)
# Tweet(id=998403366957957120, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-21 03:21:26+00:00)
# Tweet(id=904256648981561345, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-09-03 08:16:00+00:00)
# Tweet(id=1712391114479833130, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2023-10-12 08:53:51+00:00)
# Tweet(id=1321765560233811970, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-10-29 10:47:21+00:00)
# Tweet(id=1074672068434640896, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-12-17 14:26:02+00:00)
# Tweet(id=997702881762459648, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-05-19 04:57:58+00:00)
# Tweet(id=1394125478210924546, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2021-05-17 02:59:50+00:00)
# Tweet(id=1722204569009303822, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2023-11-08 10:49:00+00:00)
# Tweet(id=884947793596395520, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-07-12 01:29:30+00:00)
# Tweet(id=1515939423690833932, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2022-04-18 06:24:58+00:00)
# Tweet(id=1264091805655560192, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-05-23 07:12:26+00:00)
# Tweet(id=943484860261310464, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-12-20 14:14:54+00:00)
# Tweet(id=1393804042183184385, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2021-05-16 05:42:33+00:00)
# Tweet(id=1144548246141800449, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-06-28 10:09:01+00:00)
# Tweet(id=980348006221443072, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-04-01 07:35:53+00:00)
# Tweet(id=1233564539335008256, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-02-29 01:27:59+00:00)
# Tweet(id=1019129166560522240, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-07-17 07:58:22+00:00)
# Tweet(id=1167444167162613761, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2019-08-30 14:29:14+00:00)
# Tweet(id=932802151876669441, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2017-11-21 02:45:38+00:00)
# Tweet(id=949909787793223680, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2018-01-07 07:45:16+00:00)
# Tweet(id=1265565480405872642, author=User(id=2974181588, username=chedetofficial, name=Dr Mahathir Mohamad, verified=True), created_on=2020-05-27 08:48:18+00:00)

# %%
# Calling DataFrame constructor on list

df = pd.DataFrame({'Date': tweet_date, 'Tweet':tweet_text})
df
# Out:
#                         Date  \
# 0  2020-02-25 04:44:08+00:00
# 1  2018-05-11 06:52:30+00:00
# 2  2018-05-10 05:24:52+00:00
# 3  2019-11-23 03:56:53+00:00
# 4  2018-05-17 00:01:05+00:00
# ..                       ...
# 93 2018-07-17 07:58:22+00:00
# 94 2019-08-30 14:29:14+00:00
# 95 2017-11-21 02:45:38+00:00
# 96 2018-01-07 07:45:16+00:00
# 97 2020-05-27 08:48:18+00:00
#
#                                                 Tweet
# 0   Just another day in the office. https://t.co/f...
# 1   First day on the job... once again. https://t....
# 2   Kita telah melakukan sesuatu yang selama ini m...
# 3   Sekali sekala bawa Hasmah dating di KL https:/...
# 4   Selamat menunaikan ibadah puasa dari saya dan ...
# ..                                                ...
# 93  17 Julai 2018, sesi Parlimen Malaysia ke-14 ht...
# 94  Demi negara yang tercinta dicurahkan bakti pen...
# 95  Umur bukan penghalang untuk kita belajar tekno...
# 96  Siti marah saya curi makanan dia. \nSharing is...
# 97  Hari ini K-Pop menjadi fenomena di kalangan an...
#
# [98 rows x 2 columns]

# %% [markdown]
# Save your data in the form of csv

# %%
df.to_csv("my_data.csv")

# %% [markdown]
# **Limitation:** Without Twitter User ID and password, you only can access 100 tweet from the user.

# %% [markdown]
# ### 2. Advance Functions (sign-in required)
# In order to use advance functions, you need to provide Twitter user ID, password and extra password. The extra password will be emailed to you based on your Twitter ID email.
#
# app.sign_in("USER ID", "PASSWORD", extra="EXTRA PASSWORD")

# %% [markdown]
# #### a. Get tweets from the user

# %% [markdown]
# Let us now attempt to extract Tun M's tweets. We may also set the "pages" value. If "pages" is set to 1, it will retrieve 20 tweets per page. Increase the value of "pages" to extract more tweets.

# %%
app.sign_in("Aremien1096206", "@Taiping1234")
# Out:
# ---------------------------------------------------------------------------
# InvalidTweetIdentifier                    Traceback (most recent call last)
# <ipython-input-16-043fdeacafbf> in <cell line: 1>()
# ----> 1 app.sign_in("Aremien1096206", "@Taiping1234")
#
# /usr/local/lib/python3.10/dist-packages/tweety/auth.py in sign_in(self, username, password, extra)
#     106             self._login_flow_state = self._login_flow.initial_state
#     107
# --> 108         return self._login()
#     109
#     110     def load_cookies(
#
# /usr/local/lib/python3.10/dist-packages/tweety/auth.py in _login(self)
#     156         while not self.logged_in:
#     157             _login_payload = self._login_flow.get(self._login_flow_state, json_=self._last_json, username=_username, password=_password, extra=_extra)
# --> 158             response = self.request.login(self._login_url, _payload=_login_payload)
#     159
#     160             self._last_json = response.json()
#
# /usr/local/lib/python3.10/dist-packages/tweety/http.py in login(self, _url, _payload)
#     158         request_data['json'] = _payload
#     159         request_data['headers']['Content-Type'] = "application/json"
# --> 160         response = self.__get_response__(True, **request_data)
#     161         return response
#     162
#
# /usr/local/lib/python3.10/dist-packages/tweety/http.py in __get_response__(self, return_raw, ignore_none_data, is_document, **request_data)
#      93         if response_json.get("errors") and not response_json.get('data'):
#      94             error = response_json['errors'][0]
# ---> 95             return GenericError(
#      96                 response, error.get("code"), error.get("message")
#      97             )
#
# /usr/local/lib/python3.10/dist-packages/tweety/types/n_types.py in __init__(self, response, error_code, message)
#      71         self.message = message
#      72         self.retry_after = self._get_retry_after()
# ---> 73         self._raise_exception()
#      74
#      75     def _get_retry_after(self):
#
# /usr/local/lib/python3.10/dist-packages/tweety/types/n_types.py in _raise_exception(self)
#      83     def _raise_exception(self):
#      84         if self.EXCEPTIONS.get(self.error_code):
# ---> 85             raise self.EXCEPTIONS[self.error_code](
#      86                 error_code=self.error_code,
#      87                 error_name=TWITTER_ERRORS[self.error_code],
#
# InvalidTweetIdentifier: Missing data.

# %%
app.sign_in("Aremien1096206", "", extra="evc6x4y8")
target_username = "chedetofficial"
user = app.get_user_info(target_username)
all_tweets = app.get_tweets(user,pages = 10)


tweet_date = []
tweet_text = []
for x in all_tweets:
  #print(x.items)
  for k, v in x.items():
    #print("-",k)
    if(k == "date"):
      #print(">",v)
      tweet_date.append(v)
    if(k == "text"):
      #print(">",v)
      tweet_text.append(v)

# %%
# Calling DataFrame constructor on list

df = pd.DataFrame({'Date': tweet_date, 'Tweet':tweet_text})
df
# Out:
#                          Date  \
# 0   2024-04-18 09:03:53+00:00
# 1   2024-04-17 07:39:32+00:00
# 2   2024-04-16 07:54:00+00:00
# 3   2024-04-09 16:54:32+00:00
# 4   2024-04-09 13:46:58+00:00
# ..                        ...
# 153 2023-07-27 14:15:14+00:00
# 154 2023-07-27 05:24:16+00:00
# 155 2023-07-26 13:37:52+00:00
# 156 2023-07-26 07:45:24+00:00
# 157 2023-07-26 02:23:52+00:00
#
#                                                  Tweet
# 0    𝐓𝐔𝐃𝐔𝐇𝐀𝐍\n\n1. Membuat tuduhan mudah. Tetapi tu...
# 1    𝐋𝐀𝐖 𝐀𝐒 𝐀 𝐌𝐄𝐀𝐍𝐒 𝐓𝐎 𝐓𝐇𝐑𝐄𝐀𝐓𝐄𝐍\n \n1. We believe i...
# 2    APAKAH SAYA PENJENAYAH\n\n1. Kata Inspector-Ge...
# 3    Saya ingin mengucapkan Selamat Menyambut Hari ...
# 4    Dr Mahathir juga mengingatkan rakyat supaya ti...
# ..                                                 ...
# 153  WHO OWNS THE COUNTRY\n \n1. Ownership of a cou...
# 154  MALAYSIA A MALAY COUNTRY\n \n1. Stop talking a...
# 155  MULTIRACIALISM\n \n1. The Government and its s...
# 156  RACE\n\n1. The people are not allowed to creat...
# 157  3R LAWS\n\n1. The Law Minister says the Govern...
#
# [158 rows x 2 columns]

# %%
df.to_csv("my_data_chedet.csv")

# %% [markdown]
# #### b. Searching a keyword
# Do you have a specific topic or subject that you want to collect from Twitter? We can use searching a keyword function to get them. In order to search tweets, you need to provide such information:
#
# *   keywords : example #UKM, paracetamol, pulau redang, etc..
# *   nunmber of Tweet pages you want to get
# *   Filter (optional) : Filter you would like to apply on the search.
# *   Wait time: Number of seconds to wait between multiple requests
#
# In this case, we'd want to get tweets on Fukushima water waste. As we all know, Japan began dumping treated radioactive water into the Pacific Ocean from the stricken Fukushima nuclear power plant. To obtain the information, we must first find relevant terms, such as "fukushima waste water" or "fukushima radiation water." Each query will get different results.
#
# **Note:** Don't worry if you get Error 500 when looking for data. It is only a momentary issue that indicates "Something is broken. This is generally a transitory mistake, such as when a server is under heavy load or an endpoint is experiencing problems". Grab a coffee and after a few minutes try again with a lower page number.

# %%
from tweety.filters import SearchFilters

tweets = app.search("Gaza", pages = 10, filter_=SearchFilters.Latest(), wait_time = 2)

tweet_text = []
tweet_date = []
for tweet in tweets:
  tweet_text.append(tweet.text)
  tweet_date.append(tweet.date)

df = pd.DataFrame({'Date': tweet_date, 'Tweet':tweet_text})
df
# Out:
#                          Date  \
# 0   2024-04-23 09:44:36+00:00
# 1   2024-04-23 09:44:33+00:00
# 2   2024-04-23 09:44:31+00:00
# 3   2024-04-23 09:44:31+00:00
# 4   2024-04-23 09:44:31+00:00
# ..                        ...
# 124 2024-04-23 09:42:26+00:00
# 125 2024-04-23 09:42:24+00:00
# 126 2024-04-23 09:42:15+00:00
# 127 2024-04-23 09:42:10+00:00
# 128 2024-04-23 09:42:10+00:00
#
#                                                  Tweet
# 0    Mass-Arrests-Made-As-US-Campus-Protests-Over-G...
# 1    @DrLoupis 90% of the residents of Gaza are now...
# 2    @Kingbuster9903 @2szszs @exsdel @HowidyHamza A...
# 3    @alon_mizrahi So pathetic https://t.co/6MrASAOS7K
# 4    @OliLondonTV Lock em up, then deport them to G...
# ..                                                 ...
# 124  @ionebelarra @MartinaVelardeG @NicoSguiglia lo...
# 125  #ريال_مدريد\n#غزة\n#فلسطين\n#RealMadrid\n#Gaza...
# 126  200 يوم من الإبادة والقتل والتهجير والرعب وفقد...
# 127  @Sprinterfactory Put them on a fukn plane to Gaza
# 128  NYU faculty form a chain around Gaza Solidarit...
#
# [129 rows x 2 columns]

# %% [markdown]
# In this example, I'll name my file my_data.csv. You may change the file's name accordingly.

# %%
df.to_csv("gaza.csv")

# %% [markdown]
# We also can filter/search for users by using user name. In this example, we search for

# %% [markdown]
# ##**Self Activity: Collect Data From Twitter**
# Now, you can collect your own social media data.

# %% [markdown]
# 1. You may use the given template to collect your own dataset based on Twitter user

# %%
# Which user's tweets would you like to search for
target_username = "elonmusk" #change to your target username

user = app.get_user_info(target_username)
all_tweets = app.get_tweets(user,pages = 20 )

# save to data: date and tweet text
tweet_date = []
tweet_text = []
for x in all_tweets:
  #print(x.items)
  for k, v in x.items():
    #print("-",k)
    if(k == "date"):
      #print(">",v)
      tweet_date.append(v)
    if(k == "text"):
      #print(">",v)
      tweet_text.append(v)

#save the data into dataframe
df = pd.DataFrame({'Date': tweet_date, 'Tweet':tweet_text})

#save the data in csv format
df.to_csv("my_data1.csv") # you may change the data name accordingly.

# %% [markdown]
# 2. Search for any topic of your interest.

# %%
tweets = app.search("airasia", pages = 10, filter_=SearchFilters.Latest(), wait_time = 10)

tweet_text = []
tweet_date = []
for tweet in tweets:
  tweet_text.append(tweet.text)
  tweet_date.append(tweet.date)

df = pd.DataFrame({'Date': tweet_date, 'Tweet':tweet_text})

#save the data in csv format
df.to_csv("my_data2.csv") # you may change the data name accordingly.
