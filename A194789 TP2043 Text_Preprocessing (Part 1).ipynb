# %% [markdown]
# Student Name : MUHAMMAD AJRUL AMIN BIN MOHD ZAIDI
#
# Student Number : A194789

# %% [markdown]
# **Convert text to lowercase.**
#
# Example 1. Convert text to lowercase

# %%
input_str = "The 5 biggest countries by population in 2017 are China, India, United States, Indonesia, and Brazil."
input_str = input_str.upper() # input_str.upper() #lower
print(input_str)
# Out:
# THE 5 BIGGEST COUNTRIES BY POPULATION IN 2017 ARE CHINA, INDIA, UNITED STATES, INDONESIA, AND BRAZIL.

# %% [markdown]
# **Remove numbers**

# %%
import re # regular expression (to remove numbers)
input_str = "Box A contains 3 red and 5 white balls, while Box B contains 4 red and 2 blue balls."
result = re.sub(r'\d+', '', input_str)
print(result)
# Out:
# Box A contains  red and  white balls, while Box B contains  red and  blue balls.

# %% [markdown]
# **Remove punctuation**
#
# The following code removes this set of symbols [!”#$%&’()*+,-./:;<=>?@[\]^_`{|}~]:

# %%
import string
input_str = "This &is [an] example? {of} string. with.? punctuation!!!!" # Sample string

result = input_str.translate(str.maketrans('', '', string.punctuation))
print(result)
# Out:
# This is an example of string with punctuation

# %% [markdown]
# **Remove whitespaces**
#
# To remove leading and ending spaces, you can use the strip() function:

# %%
input_str = " \t a string example\t "
input_str = input_str.strip()
input_str
# Out:
# 'a string example'

# %% [markdown]
# **Remove stop words and tokenization**
#
# “Stop words” are the most common words in a language like “the”, “a”, “on”, “is”, “all”. These words do not carry important meaning and are usually removed from texts. It is possible to remove stop words using Natural Language Toolkit (NLTK), a suite of libraries and programs for symbolic and statistical natural language processing.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
input_str = "Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus."
print("\nInput sentence :",input_str)
stop_words = set(stopwords.words('english'))
from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)
print("\nWord tokenization output:")
print(tokens)
result = [i for i in tokens if not i in stop_words]
for word in result:
  print(word)
print (result)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Input sentence : Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus.
#
# Word tokenization output:
# ['Coronavirus', 'disease', '(', 'COVID-19', ')', 'is', 'an', 'infectious', 'disease', 'caused', 'by', 'the', 'SARS-CoV-2', 'virus', '.']
# Coronavirus
# disease
# (
# COVID-19
# )
# infectious
# disease
# caused
# SARS-CoV-2
# virus
# .
# ['Coronavirus', 'disease', '(', 'COVID-19', ')', 'infectious', 'disease', 'caused', 'SARS-CoV-2', 'virus', '.']

# %% [markdown]
# ## Convert accented characters to ASCII characters

# %% [markdown]
# Accent marks (also referred to as diacritics or diacriticals) usually appear above a character when we press the character for a long time. These need to be remove cause the model cannot distinguish between "dèèp" and "deep". It will consider them as two different words.

# %%
# !pip install unidecode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 3.7 MB/s eta 0:00:00
# ...

# %%
import unidecode

# %%
def accented_to_ascii(text):
    return unidecode.unidecode(text)

# %%
text = "This is an example text with accented characters like dèèp lèarning ánd cömputer vísíön etc."
accented_to_ascii(text)
# Out:
# 'This is an example text with accented characters like deep learning and computer vision etc.'

# %% [markdown]
# ## Task 1: Clean the given text by combining some of the preprocessing techniques that you have learn.
#
# The quick brown fox jumps over the lazy dog. The dog, startled, wakes up and starts barking loudly. The fox, unfazed, continues its graceful leap over the fence. Nearby, a squirrel watches the scene with amusement from the safety of a tree branch. The sun shines brightly, casting a warm glow over the peaceful meadow.

# %%
import string
text = "The quick brown fox jumps over the lazy dog. The dog, startled, wakes up and starts barking loudly. The fox, unfazed, continues its graceful leap over the fence. Nearby, a squirrel watches the scene with amusement from the safety of a tree branch. The sun shines brightly, casting a warm glow over the peaceful meadow."
# set to lower case
text_lower = text.lower()
print("Lower Case : " ,text_lower)

# remove punctuations
text_remove_punct = text_lower.translate(str.maketrans('', '', string.punctuation))
print("Remove punctuation : ",text_remove_punct)


# tokenize and remove stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
print("\nInput sentence :",text_remove_punct)
stop_words = set(stopwords.words('english'))
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text_remove_punct)
print("\nWord tokenization output:")
print("Before stopword removal : " ,tokens)
result = [i for i in tokens if not i in stop_words]
# for word in result:
#  print(word)
print ("After stopword removal : " ,result)
# Out:
# Lower Case :  the quick brown fox jumps over the lazy dog. the dog, startled, wakes up and starts barking loudly. the fox, unfazed, continues its graceful leap over the fence. nearby, a squirrel watches the scene with amusement from the safety of a tree branch. the sun shines brightly, casting a warm glow over the peaceful meadow.
# Remove punctuation :  the quick brown fox jumps over the lazy dog the dog startled wakes up and starts barking loudly the fox unfazed continues its graceful leap over the fence nearby a squirrel watches the scene with amusement from the safety of a tree branch the sun shines brightly casting a warm glow over the peaceful meadow
#
# Input sentence : the quick brown fox jumps over the lazy dog the dog startled wakes up and starts barking loudly the fox unfazed continues its graceful leap over the fence nearby a squirrel watches the scene with amusement from the safety of a tree branch the sun shines brightly casting a warm glow over the peaceful meadow
#
# ...
