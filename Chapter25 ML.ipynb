# %%
from pandas import read_csv
import matplotlib.pyplot as plt
dataset = read_csv( 'international-airline-passengers.csv' , usecols=[1], engine= 'python' )
plt.plot(dataset)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
# load the dataset
dataframe = read_csv('international-airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 97 48

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# create and fit Multilayer Perceptron model
model = Sequential()
model.add(Dense(8, input_dim=look_back, activation= 'relu' ))
model.add(Dense(1))
model.compile(loss='mean_squared_error' , optimizer= 'adam' )
model.fit(trainX, trainY, epochs=200, batch_size=2, verbose=2)
# Out:
# Epoch 1/200
# 48/48 - 1s - loss: 70087.6016 - 1s/epoch - 22ms/step
# Epoch 2/200
# 48/48 - 0s - loss: 58173.2578 - 111ms/epoch - 2ms/step
# Epoch 3/200
# 48/48 - 0s - loss: 47985.8281 - 109ms/epoch - 2ms/step
# Epoch 4/200
# 48/48 - 0s - loss: 39111.7227 - 122ms/epoch - 3ms/step
# Epoch 5/200
# 48/48 - 0s - loss: 30920.8457 - 137ms/epoch - 3ms/step
# Epoch 6/200
# 48/48 - 0s - loss: 23397.3047 - 130ms/epoch - 3ms/step
# Epoch 7/200
# 48/48 - 0s - loss: 16897.7148 - 125ms/epoch - 3ms/step
# Epoch 8/200
# 48/48 - 0s - loss: 11645.8369 - 120ms/epoch - 3ms/step
# Epoch 9/200
# 48/48 - 0s - loss: 7613.3877 - 100ms/epoch - 2ms/step
# Epoch 10/200
# 48/48 - 0s - loss: 4734.7891 - 134ms/epoch - 3ms/step
# Epoch 11/200
# 48/48 - 0s - loss: 2851.7271 - 121ms/epoch - 3ms/step
# Epoch 12/200
# 48/48 - 0s - loss: 1687.4343 - 113ms/epoch - 2ms/step
# Epoch 13/200
# 48/48 - 0s - loss: 1074.7572 - 78ms/epoch - 2ms/step
# Epoch 14/200
# 48/48 - 0s - loss: 773.2576 - 71ms/epoch - 1ms/step
# Epoch 15/200
# 48/48 - 0s - loss: 636.8669 - 72ms/epoch - 1ms/step
# Epoch 16/200
# 48/48 - 0s - loss: 582.5577 - 71ms/epoch - 1ms/step
# Epoch 17/200
# 48/48 - 0s - loss: 555.7772 - 70ms/epoch - 1ms/step
# Epoch 18/200
# 48/48 - 0s - loss: 549.3043 - 92ms/epoch - 2ms/step
# Epoch 19/200
# 48/48 - 0s - loss: 547.0731 - 78ms/epoch - 2ms/step
# Epoch 20/200
# 48/48 - 0s - loss: 543.5343 - 75ms/epoch - 2ms/step
# Epoch 21/200
# 48/48 - 0s - loss: 543.8860 - 83ms/epoch - 2ms/step
# Epoch 22/200
# 48/48 - 0s - loss: 543.3257 - 72ms/epoch - 1ms/step
# Epoch 23/200
# 48/48 - 0s - loss: 547.9852 - 77ms/epoch - 2ms/step
# Epoch 24/200
# 48/48 - 0s - loss: 542.8956 - 75ms/epoch - 2ms/step
# Epoch 25/200
# 48/48 - 0s - loss: 544.1919 - 76ms/epoch - 2ms/step
# Epoch 26/200
# 48/48 - 0s - loss: 547.8770 - 81ms/epoch - 2ms/step
# Epoch 27/200
# 48/48 - 0s - loss: 543.8853 - 76ms/epoch - 2ms/step
# Epoch 28/200
# 48/48 - 0s - loss: 544.0342 - 81ms/epoch - 2ms/step
# Epoch 29/200
# 48/48 - 0s - loss: 543.5103 - 78ms/epoch - 2ms/step
# Epoch 30/200
# 48/48 - 0s - loss: 543.4811 - 80ms/epoch - 2ms/step
# Epoch 31/200
# 48/48 - 0s - loss: 543.2839 - 93ms/epoch - 2ms/step
# Epoch 32/200
# 48/48 - 0s - loss: 544.0716 - 77ms/epoch - 2ms/step
# Epoch 33/200
# 48/48 - 0s - loss: 543.1597 - 69ms/epoch - 1ms/step
# Epoch 34/200
# 48/48 - 0s - loss: 544.9377 - 79ms/epoch - 2ms/step
# Epoch 35/200
# 48/48 - 0s - loss: 545.1839 - 75ms/epoch - 2ms/step
# Epoch 36/200
# 48/48 - 0s - loss: 541.9519 - 87ms/epoch - 2ms/step
# Epoch 37/200
# 48/48 - 0s - loss: 543.0051 - 80ms/epoch - 2ms/step
# Epoch 38/200
# 48/48 - 0s - loss: 542.2676 - 74ms/epoch - 2ms/step
# Epoch 39/200
# 48/48 - 0s - loss: 542.2004 - 75ms/epoch - 2ms/step
# Epoch 40/200
# 48/48 - 0s - loss: 545.2250 - 74ms/epoch - 2ms/step
# Epoch 41/200
# 48/48 - 0s - loss: 540.8104 - 79ms/epoch - 2ms/step
# Epoch 42/200
# 48/48 - 0s - loss: 543.8049 - 68ms/epoch - 1ms/step
# Epoch 43/200
# 48/48 - 0s - loss: 543.1619 - 76ms/epoch - 2ms/step
# Epoch 44/200
# 48/48 - 0s - loss: 544.0941 - 82ms/epoch - 2ms/step
# Epoch 45/200
# 48/48 - 0s - loss: 540.5808 - 73ms/epoch - 2ms/step
# Epoch 46/200
# 48/48 - 0s - loss: 544.9114 - 80ms/epoch - 2ms/step
# Epoch 47/200
# 48/48 - 0s - loss: 545.4952 - 71ms/epoch - 1ms/step
# Epoch 48/200
# 48/48 - 0s - loss: 542.9318 - 69ms/epoch - 1ms/step
# Epoch 49/200
# 48/48 - 0s - loss: 543.1407 - 68ms/epoch - 1ms/step
# Epoch 50/200
# 48/48 - 0s - loss: 546.3616 - 72ms/epoch - 1ms/step
# Epoch 51/200
# 48/48 - 0s - loss: 545.6891 - 70ms/epoch - 1ms/step
# Epoch 52/200
# 48/48 - 0s - loss: 547.1981 - 73ms/epoch - 2ms/step
# Epoch 53/200
# 48/48 - 0s - loss: 542.9190 - 82ms/epoch - 2ms/step
# Epoch 54/200
# 48/48 - 0s - loss: 557.7032 - 76ms/epoch - 2ms/step
# Epoch 55/200
# 48/48 - 0s - loss: 545.7963 - 69ms/epoch - 1ms/step
# Epoch 56/200
# 48/48 - 0s - loss: 549.8602 - 79ms/epoch - 2ms/step
# Epoch 57/200
# 48/48 - 0s - loss: 545.9477 - 91ms/epoch - 2ms/step
# Epoch 58/200
# 48/48 - 0s - loss: 546.3484 - 79ms/epoch - 2ms/step
# Epoch 59/200
# 48/48 - 0s - loss: 557.8802 - 82ms/epoch - 2ms/step
# Epoch 60/200
# 48/48 - 0s - loss: 551.2460 - 69ms/epoch - 1ms/step
# Epoch 61/200
# 48/48 - 0s - loss: 544.6844 - 70ms/epoch - 1ms/step
# Epoch 62/200
# 48/48 - 0s - loss: 545.8529 - 70ms/epoch - 1ms/step
# Epoch 63/200
# 48/48 - 0s - loss: 550.1536 - 83ms/epoch - 2ms/step
# Epoch 64/200
# 48/48 - 0s - loss: 543.7117 - 73ms/epoch - 2ms/step
# Epoch 65/200
# 48/48 - 0s - loss: 545.4941 - 70ms/epoch - 1ms/step
# Epoch 66/200
# 48/48 - 0s - loss: 553.3958 - 78ms/epoch - 2ms/step
# Epoch 67/200
# 48/48 - 0s - loss: 546.7943 - 74ms/epoch - 2ms/step
# Epoch 68/200
# 48/48 - 0s - loss: 543.6981 - 89ms/epoch - 2ms/step
# Epoch 69/200
# 48/48 - 0s - loss: 543.2506 - 88ms/epoch - 2ms/step
# Epoch 70/200
# 48/48 - 0s - loss: 548.2420 - 74ms/epoch - 2ms/step
# Epoch 71/200
# 48/48 - 0s - loss: 546.2741 - 79ms/epoch - 2ms/step
# Epoch 72/200
# 48/48 - 0s - loss: 548.6429 - 73ms/epoch - 2ms/step
# Epoch 73/200
# 48/48 - 0s - loss: 545.7100 - 70ms/epoch - 1ms/step
# Epoch 74/200
# 48/48 - 0s - loss: 550.0728 - 72ms/epoch - 2ms/step
# Epoch 75/200
# 48/48 - 0s - loss: 544.7089 - 74ms/epoch - 2ms/step
# Epoch 76/200
# 48/48 - 0s - loss: 543.0020 - 74ms/epoch - 2ms/step
# Epoch 77/200
# 48/48 - 0s - loss: 541.7631 - 76ms/epoch - 2ms/step
# Epoch 78/200
# 48/48 - 0s - loss: 550.3792 - 73ms/epoch - 2ms/step
# Epoch 79/200
# 48/48 - 0s - loss: 549.8753 - 71ms/epoch - 1ms/step
# Epoch 80/200
# 48/48 - 0s - loss: 543.9130 - 76ms/epoch - 2ms/step
# Epoch 81/200
# 48/48 - 0s - loss: 550.1146 - 77ms/epoch - 2ms/step
# Epoch 82/200
# 48/48 - 0s - loss: 554.0526 - 78ms/epoch - 2ms/step
# Epoch 83/200
# 48/48 - 0s - loss: 557.3054 - 76ms/epoch - 2ms/step
# Epoch 84/200
# 48/48 - 0s - loss: 548.0255 - 69ms/epoch - 1ms/step
# Epoch 85/200
# 48/48 - 0s - loss: 561.9989 - 72ms/epoch - 2ms/step
# Epoch 86/200
# 48/48 - 0s - loss: 548.4589 - 68ms/epoch - 1ms/step
# Epoch 87/200
# 48/48 - 0s - loss: 551.4997 - 72ms/epoch - 1ms/step
# Epoch 88/200
# 48/48 - 0s - loss: 547.4790 - 73ms/epoch - 2ms/step
# Epoch 89/200
# 48/48 - 0s - loss: 551.0331 - 86ms/epoch - 2ms/step
# Epoch 90/200
# 48/48 - 0s - loss: 545.8378 - 75ms/epoch - 2ms/step
# Epoch 91/200
# 48/48 - 0s - loss: 542.7885 - 70ms/epoch - 1ms/step
# Epoch 92/200
# 48/48 - 0s - loss: 542.9028 - 80ms/epoch - 2ms/step
# Epoch 93/200
# 48/48 - 0s - loss: 557.7348 - 81ms/epoch - 2ms/step
# Epoch 94/200
# 48/48 - 0s - loss: 551.3401 - 77ms/epoch - 2ms/step
# Epoch 95/200
# 48/48 - 0s - loss: 547.6729 - 75ms/epoch - 2ms/step
# Epoch 96/200
# 48/48 - 0s - loss: 559.0681 - 83ms/epoch - 2ms/step
# Epoch 97/200
# 48/48 - 0s - loss: 541.0450 - 78ms/epoch - 2ms/step
# Epoch 98/200
# 48/48 - 0s - loss: 546.5000 - 69ms/epoch - 1ms/step
# Epoch 99/200
# 48/48 - 0s - loss: 543.7776 - 71ms/epoch - 1ms/step
# Epoch 100/200
# 48/48 - 0s - loss: 553.5322 - 69ms/epoch - 1ms/step
# Epoch 101/200
# 48/48 - 0s - loss: 551.5032 - 73ms/epoch - 2ms/step
# Epoch 102/200
# 48/48 - 0s - loss: 545.6296 - 85ms/epoch - 2ms/step
# Epoch 103/200
# 48/48 - 0s - loss: 544.9036 - 71ms/epoch - 1ms/step
# Epoch 104/200
# 48/48 - 0s - loss: 548.5981 - 84ms/epoch - 2ms/step
# Epoch 105/200
# 48/48 - 0s - loss: 549.1147 - 76ms/epoch - 2ms/step
# Epoch 106/200
# 48/48 - 0s - loss: 550.4537 - 77ms/epoch - 2ms/step
# Epoch 107/200
# 48/48 - 0s - loss: 548.1286 - 73ms/epoch - 2ms/step
# Epoch 108/200
# 48/48 - 0s - loss: 545.5924 - 89ms/epoch - 2ms/step
# Epoch 109/200
# 48/48 - 0s - loss: 550.4523 - 76ms/epoch - 2ms/step
# Epoch 110/200
# 48/48 - 0s - loss: 545.0461 - 85ms/epoch - 2ms/step
# Epoch 111/200
# 48/48 - 0s - loss: 547.6516 - 70ms/epoch - 1ms/step
# Epoch 112/200
# 48/48 - 0s - loss: 544.5741 - 78ms/epoch - 2ms/step
# Epoch 113/200
# 48/48 - 0s - loss: 555.6905 - 70ms/epoch - 1ms/step
# Epoch 114/200
# 48/48 - 0s - loss: 547.3326 - 76ms/epoch - 2ms/step
# Epoch 115/200
# 48/48 - 0s - loss: 556.7068 - 81ms/epoch - 2ms/step
# Epoch 116/200
# 48/48 - 0s - loss: 551.2379 - 80ms/epoch - 2ms/step
# Epoch 117/200
# 48/48 - 0s - loss: 541.8647 - 84ms/epoch - 2ms/step
# Epoch 118/200
# 48/48 - 0s - loss: 543.9474 - 75ms/epoch - 2ms/step
# Epoch 119/200
# 48/48 - 0s - loss: 545.9973 - 67ms/epoch - 1ms/step
# Epoch 120/200
# 48/48 - 0s - loss: 540.6193 - 70ms/epoch - 1ms/step
# Epoch 121/200
# 48/48 - 0s - loss: 552.6017 - 87ms/epoch - 2ms/step
# Epoch 122/200
# 48/48 - 0s - loss: 547.1208 - 72ms/epoch - 2ms/step
# Epoch 123/200
# 48/48 - 0s - loss: 545.5135 - 72ms/epoch - 1ms/step
# Epoch 124/200
# 48/48 - 0s - loss: 543.1179 - 71ms/epoch - 1ms/step
# Epoch 125/200
# 48/48 - 0s - loss: 542.6672 - 71ms/epoch - 1ms/step
# Epoch 126/200
# 48/48 - 0s - loss: 549.6666 - 71ms/epoch - 1ms/step
# Epoch 127/200
# 48/48 - 0s - loss: 544.9534 - 80ms/epoch - 2ms/step
# Epoch 128/200
# 48/48 - 0s - loss: 550.8108 - 76ms/epoch - 2ms/step
# Epoch 129/200
# 48/48 - 0s - loss: 549.8311 - 80ms/epoch - 2ms/step
# Epoch 130/200
# 48/48 - 0s - loss: 548.9330 - 69ms/epoch - 1ms/step
# Epoch 131/200
# 48/48 - 0s - loss: 549.8622 - 79ms/epoch - 2ms/step
# Epoch 132/200
# 48/48 - 0s - loss: 550.2596 - 70ms/epoch - 1ms/step
# Epoch 133/200
# 48/48 - 0s - loss: 566.3476 - 73ms/epoch - 2ms/step
# Epoch 134/200
# 48/48 - 0s - loss: 552.0879 - 90ms/epoch - 2ms/step
# Epoch 135/200
# 48/48 - 0s - loss: 549.3240 - 67ms/epoch - 1ms/step
# Epoch 136/200
# 48/48 - 0s - loss: 552.9039 - 78ms/epoch - 2ms/step
# Epoch 137/200
# 48/48 - 0s - loss: 552.2285 - 69ms/epoch - 1ms/step
# Epoch 138/200
# 48/48 - 0s - loss: 562.0339 - 93ms/epoch - 2ms/step
# Epoch 139/200
# 48/48 - 0s - loss: 545.0667 - 99ms/epoch - 2ms/step
# Epoch 140/200
# 48/48 - 0s - loss: 547.3740 - 99ms/epoch - 2ms/step
# Epoch 141/200
# 48/48 - 0s - loss: 544.9029 - 110ms/epoch - 2ms/step
# Epoch 142/200
# 48/48 - 0s - loss: 544.7101 - 99ms/epoch - 2ms/step
# Epoch 143/200
# 48/48 - 0s - loss: 544.4839 - 118ms/epoch - 2ms/step
# Epoch 144/200
# 48/48 - 0s - loss: 549.2545 - 118ms/epoch - 2ms/step
# Epoch 145/200
# 48/48 - 0s - loss: 546.3177 - 125ms/epoch - 3ms/step
# Epoch 146/200
# 48/48 - 0s - loss: 544.4283 - 112ms/epoch - 2ms/step
# Epoch 147/200
# 48/48 - 0s - loss: 551.3837 - 89ms/epoch - 2ms/step
# Epoch 148/200
# 48/48 - 0s - loss: 544.1272 - 100ms/epoch - 2ms/step
# Epoch 149/200
# 48/48 - 0s - loss: 540.7662 - 98ms/epoch - 2ms/step
# Epoch 150/200
# 48/48 - 0s - loss: 542.0692 - 108ms/epoch - 2ms/step
# Epoch 151/200
# 48/48 - 0s - loss: 545.9122 - 94ms/epoch - 2ms/step
# Epoch 152/200
# 48/48 - 0s - loss: 548.4374 - 90ms/epoch - 2ms/step
# Epoch 153/200
# 48/48 - 0s - loss: 558.6275 - 103ms/epoch - 2ms/step
# Epoch 154/200
# 48/48 - 0s - loss: 552.6766 - 116ms/epoch - 2ms/step
# Epoch 155/200
# 48/48 - 0s - loss: 553.4865 - 118ms/epoch - 2ms/step
# Epoch 156/200
# 48/48 - 0s - loss: 543.5555 - 120ms/epoch - 2ms/step
# Epoch 157/200
# 48/48 - 0s - loss: 542.2033 - 111ms/epoch - 2ms/step
# Epoch 158/200
# 48/48 - 0s - loss: 553.3939 - 124ms/epoch - 3ms/step
# Epoch 159/200
# 48/48 - 0s - loss: 543.9127 - 108ms/epoch - 2ms/step
# Epoch 160/200
# 48/48 - 0s - loss: 548.1829 - 122ms/epoch - 3ms/step
# Epoch 161/200
# 48/48 - 0s - loss: 542.6758 - 97ms/epoch - 2ms/step
# Epoch 162/200
# 48/48 - 0s - loss: 544.2008 - 106ms/epoch - 2ms/step
# Epoch 163/200
# 48/48 - 0s - loss: 546.1179 - 102ms/epoch - 2ms/step
# Epoch 164/200
# 48/48 - 0s - loss: 541.7882 - 103ms/epoch - 2ms/step
# Epoch 165/200
# 48/48 - 0s - loss: 548.1093 - 124ms/epoch - 3ms/step
# Epoch 166/200
# 48/48 - 0s - loss: 546.9892 - 120ms/epoch - 2ms/step
# Epoch 167/200
# 48/48 - 0s - loss: 545.1556 - 116ms/epoch - 2ms/step
# Epoch 168/200
# 48/48 - 0s - loss: 554.6940 - 79ms/epoch - 2ms/step
# Epoch 169/200
# 48/48 - 0s - loss: 539.8577 - 81ms/epoch - 2ms/step
# Epoch 170/200
# 48/48 - 0s - loss: 540.8146 - 68ms/epoch - 1ms/step
# Epoch 171/200
# 48/48 - 0s - loss: 549.0874 - 74ms/epoch - 2ms/step
# Epoch 172/200
# 48/48 - 0s - loss: 548.2391 - 76ms/epoch - 2ms/step
# Epoch 173/200
# 48/48 - 0s - loss: 550.0620 - 75ms/epoch - 2ms/step
# Epoch 174/200
# 48/48 - 0s - loss: 548.9584 - 76ms/epoch - 2ms/step
# Epoch 175/200
# 48/48 - 0s - loss: 546.8828 - 82ms/epoch - 2ms/step
# Epoch 176/200
# 48/48 - 0s - loss: 545.5005 - 68ms/epoch - 1ms/step
# Epoch 177/200
# 48/48 - 0s - loss: 544.2047 - 70ms/epoch - 1ms/step
# Epoch 178/200
# 48/48 - 0s - loss: 549.5055 - 72ms/epoch - 2ms/step
# Epoch 179/200
# 48/48 - 0s - loss: 556.1110 - 89ms/epoch - 2ms/step
# Epoch 180/200
# 48/48 - 0s - loss: 540.9380 - 75ms/epoch - 2ms/step
# Epoch 181/200
# 48/48 - 0s - loss: 552.1240 - 71ms/epoch - 1ms/step
# Epoch 182/200
# 48/48 - 0s - loss: 539.7115 - 75ms/epoch - 2ms/step
# Epoch 183/200
# 48/48 - 0s - loss: 548.3994 - 71ms/epoch - 1ms/step
# Epoch 184/200
# 48/48 - 0s - loss: 542.2773 - 78ms/epoch - 2ms/step
# Epoch 185/200
# 48/48 - 0s - loss: 551.1049 - 75ms/epoch - 2ms/step
# Epoch 186/200
# 48/48 - 0s - loss: 551.6005 - 82ms/epoch - 2ms/step
# Epoch 187/200
# 48/48 - 0s - loss: 547.1810 - 81ms/epoch - 2ms/step
# Epoch 188/200
# 48/48 - 0s - loss: 542.8851 - 85ms/epoch - 2ms/step
# Epoch 189/200
# 48/48 - 0s - loss: 544.0230 - 69ms/epoch - 1ms/step
# Epoch 190/200
# 48/48 - 0s - loss: 556.2584 - 73ms/epoch - 2ms/step
# Epoch 191/200
# 48/48 - 0s - loss: 545.2729 - 71ms/epoch - 1ms/step
# Epoch 192/200
# 48/48 - 0s - loss: 546.1882 - 76ms/epoch - 2ms/step
# Epoch 193/200
# 48/48 - 0s - loss: 541.7408 - 74ms/epoch - 2ms/step
# Epoch 194/200
# 48/48 - 0s - loss: 545.6230 - 82ms/epoch - 2ms/step
# Epoch 195/200
# 48/48 - 0s - loss: 546.4760 - 76ms/epoch - 2ms/step
# Epoch 196/200
# 48/48 - 0s - loss: 542.6837 - 79ms/epoch - 2ms/step
# Epoch 197/200
# 48/48 - 0s - loss: 542.1639 - 77ms/epoch - 2ms/step
# Epoch 198/200
# 48/48 - 0s - loss: 544.4368 - 84ms/epoch - 2ms/step
# Epoch 199/200
# 48/48 - 0s - loss: 543.5819 - 78ms/epoch - 2ms/step
# Epoch 200/200
# 48/48 - 0s - loss: 543.8033 - 84ms/epoch - 2ms/step

# %%
# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 537.04 MSE (23.17 RMSE)
# Test Score: 2384.45 MSE (48.83 RMSE)

# %%
# generate predictions for training
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 3/3 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step

# %%
# Multilayer Perceptron to Predict International Airline Passengers (t+1, given t)
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return numpy.array(dataX), numpy.array(dataY)

# fix random seed for reproducibility
numpy.random.seed(7)

# load the dataset
dataframe = read_csv('international-airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# create and fit Multilayer Perceptron model
model = Sequential()
model.add(Dense(8, input_dim=look_back, activation= 'relu'))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error' , optimizer= 'adam' )
model.fit(trainX, trainY, epochs=200, batch_size=2, verbose=2)

# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))

# generate predictions for training
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/200
# 48/48 - 1s - loss: 9994.5332 - 623ms/epoch - 13ms/step
# Epoch 2/200
# 48/48 - 0s - loss: 5386.9727 - 77ms/epoch - 2ms/step
# Epoch 3/200
# 48/48 - 0s - loss: 2432.0730 - 78ms/epoch - 2ms/step
# Epoch 4/200
# 48/48 - 0s - loss: 1070.3281 - 79ms/epoch - 2ms/step
# Epoch 5/200
# 48/48 - 0s - loss: 649.8231 - 85ms/epoch - 2ms/step
# Epoch 6/200
# 48/48 - 0s - loss: 555.0887 - 82ms/epoch - 2ms/step
# Epoch 7/200
# 48/48 - 0s - loss: 545.8645 - 90ms/epoch - 2ms/step
# Epoch 8/200
# 48/48 - 0s - loss: 553.0888 - 72ms/epoch - 1ms/step
# Epoch 9/200
# 48/48 - 0s - loss: 549.4606 - 72ms/epoch - 1ms/step
# Epoch 10/200
# 48/48 - 0s - loss: 546.9717 - 86ms/epoch - 2ms/step
# Epoch 11/200
# 48/48 - 0s - loss: 556.5579 - 70ms/epoch - 1ms/step
# Epoch 12/200
# 48/48 - 0s - loss: 549.7393 - 73ms/epoch - 2ms/step
# Epoch 13/200
# 48/48 - 0s - loss: 552.2786 - 97ms/epoch - 2ms/step
# Epoch 14/200
# 48/48 - 0s - loss: 548.7841 - 84ms/epoch - 2ms/step
# Epoch 15/200
# 48/48 - 0s - loss: 549.0726 - 81ms/epoch - 2ms/step
# Epoch 16/200
# 48/48 - 0s - loss: 547.9801 - 89ms/epoch - 2ms/step
# Epoch 17/200
# 48/48 - 0s - loss: 556.4926 - 75ms/epoch - 2ms/step
# Epoch 18/200
# 48/48 - 0s - loss: 555.7184 - 76ms/epoch - 2ms/step
# Epoch 19/200
# 48/48 - 0s - loss: 547.8075 - 89ms/epoch - 2ms/step
# Epoch 20/200
# 48/48 - 0s - loss: 550.7817 - 72ms/epoch - 2ms/step
# Epoch 21/200
# 48/48 - 0s - loss: 555.4813 - 70ms/epoch - 1ms/step
# Epoch 22/200
# 48/48 - 0s - loss: 552.3314 - 71ms/epoch - 1ms/step
# Epoch 23/200
# 48/48 - 0s - loss: 552.1323 - 70ms/epoch - 1ms/step
# Epoch 24/200
# 48/48 - 0s - loss: 547.2089 - 73ms/epoch - 2ms/step
# Epoch 25/200
# 48/48 - 0s - loss: 550.2703 - 74ms/epoch - 2ms/step
# Epoch 26/200
# 48/48 - 0s - loss: 546.1710 - 78ms/epoch - 2ms/step
# Epoch 27/200
# 48/48 - 0s - loss: 549.9937 - 81ms/epoch - 2ms/step
# Epoch 28/200
# 48/48 - 0s - loss: 549.0781 - 84ms/epoch - 2ms/step
# Epoch 29/200
# 48/48 - 0s - loss: 552.4785 - 86ms/epoch - 2ms/step
# Epoch 30/200
# 48/48 - 0s - loss: 549.7982 - 101ms/epoch - 2ms/step
# Epoch 31/200
# 48/48 - 0s - loss: 554.4586 - 80ms/epoch - 2ms/step
# Epoch 32/200
# 48/48 - 0s - loss: 554.3748 - 90ms/epoch - 2ms/step
# Epoch 33/200
# 48/48 - 0s - loss: 560.0051 - 73ms/epoch - 2ms/step
# Epoch 34/200
# 48/48 - 0s - loss: 554.0007 - 78ms/epoch - 2ms/step
# Epoch 35/200
# 48/48 - 0s - loss: 554.7285 - 82ms/epoch - 2ms/step
# Epoch 36/200
# 48/48 - 0s - loss: 559.3911 - 75ms/epoch - 2ms/step
# Epoch 37/200
# 48/48 - 0s - loss: 552.0193 - 78ms/epoch - 2ms/step
# Epoch 38/200
# 48/48 - 0s - loss: 550.6539 - 67ms/epoch - 1ms/step
# Epoch 39/200
# 48/48 - 0s - loss: 550.1859 - 77ms/epoch - 2ms/step
# Epoch 40/200
# 48/48 - 0s - loss: 555.6554 - 73ms/epoch - 2ms/step
# Epoch 41/200
# 48/48 - 0s - loss: 553.9814 - 70ms/epoch - 1ms/step
# Epoch 42/200
# 48/48 - 0s - loss: 554.4047 - 67ms/epoch - 1ms/step
# Epoch 43/200
# 48/48 - 0s - loss: 551.4061 - 76ms/epoch - 2ms/step
# Epoch 44/200
# 48/48 - 0s - loss: 565.5414 - 73ms/epoch - 2ms/step
# Epoch 45/200
# 48/48 - 0s - loss: 549.5567 - 84ms/epoch - 2ms/step
# Epoch 46/200
# 48/48 - 0s - loss: 550.8696 - 68ms/epoch - 1ms/step
# Epoch 47/200
# 48/48 - 0s - loss: 548.1198 - 70ms/epoch - 1ms/step
# Epoch 48/200
# 48/48 - 0s - loss: 555.6302 - 75ms/epoch - 2ms/step
# Epoch 49/200
# 48/48 - 0s - loss: 551.5208 - 76ms/epoch - 2ms/step
# Epoch 50/200
# 48/48 - 0s - loss: 550.7238 - 77ms/epoch - 2ms/step
# Epoch 51/200
# 48/48 - 0s - loss: 555.6210 - 70ms/epoch - 1ms/step
# Epoch 52/200
# 48/48 - 0s - loss: 557.2978 - 82ms/epoch - 2ms/step
# Epoch 53/200
# 48/48 - 0s - loss: 547.7950 - 70ms/epoch - 1ms/step
# Epoch 54/200
# 48/48 - 0s - loss: 545.3811 - 77ms/epoch - 2ms/step
# Epoch 55/200
# 48/48 - 0s - loss: 553.0051 - 82ms/epoch - 2ms/step
# Epoch 56/200
# 48/48 - 0s - loss: 549.2985 - 84ms/epoch - 2ms/step
# Epoch 57/200
# 48/48 - 0s - loss: 581.3655 - 78ms/epoch - 2ms/step
# Epoch 58/200
# 48/48 - 0s - loss: 548.3563 - 89ms/epoch - 2ms/step
# Epoch 59/200
# 48/48 - 0s - loss: 551.3940 - 75ms/epoch - 2ms/step
# Epoch 60/200
# 48/48 - 0s - loss: 555.1703 - 75ms/epoch - 2ms/step
# Epoch 61/200
# 48/48 - 0s - loss: 553.3730 - 78ms/epoch - 2ms/step
# Epoch 62/200
# 48/48 - 0s - loss: 566.6213 - 76ms/epoch - 2ms/step
# Epoch 63/200
# 48/48 - 0s - loss: 549.3315 - 76ms/epoch - 2ms/step
# Epoch 64/200
# 48/48 - 0s - loss: 547.7963 - 83ms/epoch - 2ms/step
# Epoch 65/200
# 48/48 - 0s - loss: 555.1750 - 75ms/epoch - 2ms/step
# Epoch 66/200
# 48/48 - 0s - loss: 556.6265 - 77ms/epoch - 2ms/step
# Epoch 67/200
# 48/48 - 0s - loss: 554.1072 - 75ms/epoch - 2ms/step
# Epoch 68/200
# 48/48 - 0s - loss: 560.3929 - 81ms/epoch - 2ms/step
# Epoch 69/200
# 48/48 - 0s - loss: 547.1527 - 76ms/epoch - 2ms/step
# Epoch 70/200
# 48/48 - 0s - loss: 547.8281 - 87ms/epoch - 2ms/step
# Epoch 71/200
# 48/48 - 0s - loss: 547.9009 - 82ms/epoch - 2ms/step
# Epoch 72/200
# 48/48 - 0s - loss: 560.6909 - 113ms/epoch - 2ms/step
# Epoch 73/200
# 48/48 - 0s - loss: 564.2740 - 138ms/epoch - 3ms/step
# Epoch 74/200
# 48/48 - 0s - loss: 548.8301 - 127ms/epoch - 3ms/step
# Epoch 75/200
# 48/48 - 0s - loss: 547.1633 - 114ms/epoch - 2ms/step
# Epoch 76/200
# 48/48 - 0s - loss: 560.2987 - 113ms/epoch - 2ms/step
# Epoch 77/200
# 48/48 - 0s - loss: 552.2769 - 116ms/epoch - 2ms/step
# Epoch 78/200
# 48/48 - 0s - loss: 559.4259 - 114ms/epoch - 2ms/step
# Epoch 79/200
# 48/48 - 0s - loss: 550.7341 - 120ms/epoch - 2ms/step
# Epoch 80/200
# 48/48 - 0s - loss: 553.6702 - 106ms/epoch - 2ms/step
# Epoch 81/200
# 48/48 - 0s - loss: 546.9374 - 113ms/epoch - 2ms/step
# Epoch 82/200
# 48/48 - 0s - loss: 565.0694 - 98ms/epoch - 2ms/step
# Epoch 83/200
# 48/48 - 0s - loss: 550.9949 - 130ms/epoch - 3ms/step
# Epoch 84/200
# 48/48 - 0s - loss: 555.2507 - 115ms/epoch - 2ms/step
# Epoch 85/200
# 48/48 - 0s - loss: 547.3921 - 118ms/epoch - 2ms/step
# Epoch 86/200
# 48/48 - 0s - loss: 551.2655 - 108ms/epoch - 2ms/step
# Epoch 87/200
# 48/48 - 0s - loss: 547.0012 - 118ms/epoch - 2ms/step
# Epoch 88/200
# 48/48 - 0s - loss: 556.5986 - 119ms/epoch - 2ms/step
# Epoch 89/200
# 48/48 - 0s - loss: 556.8860 - 108ms/epoch - 2ms/step
# Epoch 90/200
# 48/48 - 0s - loss: 556.6563 - 102ms/epoch - 2ms/step
# Epoch 91/200
# 48/48 - 0s - loss: 561.3175 - 110ms/epoch - 2ms/step
# Epoch 92/200
# 48/48 - 0s - loss: 562.2999 - 108ms/epoch - 2ms/step
# Epoch 93/200
# 48/48 - 0s - loss: 559.5009 - 112ms/epoch - 2ms/step
# Epoch 94/200
# 48/48 - 0s - loss: 547.3337 - 126ms/epoch - 3ms/step
# Epoch 95/200
# 48/48 - 0s - loss: 548.7770 - 113ms/epoch - 2ms/step
# Epoch 96/200
# 48/48 - 0s - loss: 558.3839 - 138ms/epoch - 3ms/step
# Epoch 97/200
# 48/48 - 0s - loss: 556.4721 - 136ms/epoch - 3ms/step
# Epoch 98/200
# 48/48 - 0s - loss: 549.5352 - 101ms/epoch - 2ms/step
# Epoch 99/200
# 48/48 - 0s - loss: 549.9813 - 79ms/epoch - 2ms/step
# Epoch 100/200
# 48/48 - 0s - loss: 546.3179 - 84ms/epoch - 2ms/step
# Epoch 101/200
# 48/48 - 0s - loss: 553.3642 - 77ms/epoch - 2ms/step
# Epoch 102/200
# 48/48 - 0s - loss: 556.6696 - 73ms/epoch - 2ms/step
# Epoch 103/200
# 48/48 - 0s - loss: 543.6537 - 78ms/epoch - 2ms/step
# Epoch 104/200
# 48/48 - 0s - loss: 551.5071 - 75ms/epoch - 2ms/step
# Epoch 105/200
# 48/48 - 0s - loss: 549.1027 - 73ms/epoch - 2ms/step
# Epoch 106/200
# 48/48 - 0s - loss: 547.2701 - 84ms/epoch - 2ms/step
# Epoch 107/200
# 48/48 - 0s - loss: 548.1407 - 71ms/epoch - 1ms/step
# Epoch 108/200
# 48/48 - 0s - loss: 550.6732 - 87ms/epoch - 2ms/step
# Epoch 109/200
# 48/48 - 0s - loss: 552.1175 - 76ms/epoch - 2ms/step
# Epoch 110/200
# 48/48 - 0s - loss: 553.4839 - 82ms/epoch - 2ms/step
# Epoch 111/200
# 48/48 - 0s - loss: 549.5808 - 75ms/epoch - 2ms/step
# Epoch 112/200
# 48/48 - 0s - loss: 554.6565 - 83ms/epoch - 2ms/step
# Epoch 113/200
# 48/48 - 0s - loss: 552.2719 - 76ms/epoch - 2ms/step
# Epoch 114/200
# 48/48 - 0s - loss: 542.6870 - 74ms/epoch - 2ms/step
# Epoch 115/200
# 48/48 - 0s - loss: 564.8836 - 71ms/epoch - 1ms/step
# Epoch 116/200
# 48/48 - 0s - loss: 546.9125 - 74ms/epoch - 2ms/step
# Epoch 117/200
# 48/48 - 0s - loss: 555.1139 - 77ms/epoch - 2ms/step
# Epoch 118/200
# 48/48 - 0s - loss: 570.1951 - 86ms/epoch - 2ms/step
# Epoch 119/200
# 48/48 - 0s - loss: 560.3002 - 84ms/epoch - 2ms/step
# Epoch 120/200
# 48/48 - 0s - loss: 547.1725 - 71ms/epoch - 1ms/step
# Epoch 121/200
# 48/48 - 0s - loss: 550.1027 - 82ms/epoch - 2ms/step
# Epoch 122/200
# 48/48 - 0s - loss: 553.1640 - 73ms/epoch - 2ms/step
# Epoch 123/200
# 48/48 - 0s - loss: 554.2592 - 70ms/epoch - 1ms/step
# Epoch 124/200
# 48/48 - 0s - loss: 545.9426 - 80ms/epoch - 2ms/step
# Epoch 125/200
# 48/48 - 0s - loss: 546.1585 - 84ms/epoch - 2ms/step
# Epoch 126/200
# 48/48 - 0s - loss: 553.8061 - 77ms/epoch - 2ms/step
# Epoch 127/200
# 48/48 - 0s - loss: 550.1218 - 74ms/epoch - 2ms/step
# Epoch 128/200
# 48/48 - 0s - loss: 553.7274 - 87ms/epoch - 2ms/step
# Epoch 129/200
# 48/48 - 0s - loss: 560.0576 - 82ms/epoch - 2ms/step
# Epoch 130/200
# 48/48 - 0s - loss: 548.8936 - 87ms/epoch - 2ms/step
# Epoch 131/200
# 48/48 - 0s - loss: 561.6403 - 72ms/epoch - 2ms/step
# Epoch 132/200
# 48/48 - 0s - loss: 546.5536 - 79ms/epoch - 2ms/step
# Epoch 133/200
# 48/48 - 0s - loss: 548.5984 - 84ms/epoch - 2ms/step
# Epoch 134/200
# 48/48 - 0s - loss: 547.3873 - 78ms/epoch - 2ms/step
# Epoch 135/200
# 48/48 - 0s - loss: 555.6913 - 75ms/epoch - 2ms/step
# Epoch 136/200
# 48/48 - 0s - loss: 544.3555 - 83ms/epoch - 2ms/step
# Epoch 137/200
# 48/48 - 0s - loss: 550.2332 - 73ms/epoch - 2ms/step
# Epoch 138/200
# 48/48 - 0s - loss: 549.3539 - 73ms/epoch - 2ms/step
# Epoch 139/200
# 48/48 - 0s - loss: 563.1832 - 69ms/epoch - 1ms/step
# Epoch 140/200
# 48/48 - 0s - loss: 574.8151 - 79ms/epoch - 2ms/step
# Epoch 141/200
# 48/48 - 0s - loss: 571.9028 - 80ms/epoch - 2ms/step
# Epoch 142/200
# 48/48 - 0s - loss: 544.4904 - 81ms/epoch - 2ms/step
# Epoch 143/200
# 48/48 - 0s - loss: 549.4365 - 85ms/epoch - 2ms/step
# Epoch 144/200
# 48/48 - 0s - loss: 555.0663 - 88ms/epoch - 2ms/step
# Epoch 145/200
# 48/48 - 0s - loss: 556.0007 - 98ms/epoch - 2ms/step
# Epoch 146/200
# 48/48 - 0s - loss: 547.6318 - 111ms/epoch - 2ms/step
# Epoch 147/200
# 48/48 - 0s - loss: 550.0779 - 85ms/epoch - 2ms/step
# Epoch 148/200
# 48/48 - 0s - loss: 553.0670 - 94ms/epoch - 2ms/step
# Epoch 149/200
# 48/48 - 0s - loss: 554.5955 - 86ms/epoch - 2ms/step
# Epoch 150/200
# 48/48 - 0s - loss: 560.3380 - 81ms/epoch - 2ms/step
# Epoch 151/200
# 48/48 - 0s - loss: 548.1401 - 94ms/epoch - 2ms/step
# Epoch 152/200
# 48/48 - 0s - loss: 561.4052 - 77ms/epoch - 2ms/step
# Epoch 153/200
# 48/48 - 0s - loss: 545.7632 - 75ms/epoch - 2ms/step
# Epoch 154/200
# 48/48 - 0s - loss: 549.1091 - 83ms/epoch - 2ms/step
# Epoch 155/200
# 48/48 - 0s - loss: 545.0704 - 79ms/epoch - 2ms/step
# Epoch 156/200
# 48/48 - 0s - loss: 546.0318 - 79ms/epoch - 2ms/step
# Epoch 157/200
# 48/48 - 0s - loss: 546.5376 - 89ms/epoch - 2ms/step
# Epoch 158/200
# 48/48 - 0s - loss: 542.7206 - 81ms/epoch - 2ms/step
# Epoch 159/200
# 48/48 - 0s - loss: 544.8140 - 86ms/epoch - 2ms/step
# Epoch 160/200
# 48/48 - 0s - loss: 546.9002 - 86ms/epoch - 2ms/step
# Epoch 161/200
# 48/48 - 0s - loss: 555.0078 - 81ms/epoch - 2ms/step
# Epoch 162/200
# 48/48 - 0s - loss: 559.8452 - 76ms/epoch - 2ms/step
# Epoch 163/200
# 48/48 - 0s - loss: 550.5085 - 70ms/epoch - 1ms/step
# Epoch 164/200
# 48/48 - 0s - loss: 547.4127 - 79ms/epoch - 2ms/step
# Epoch 165/200
# 48/48 - 0s - loss: 546.7914 - 71ms/epoch - 1ms/step
# Epoch 166/200
# 48/48 - 0s - loss: 545.9611 - 67ms/epoch - 1ms/step
# Epoch 167/200
# 48/48 - 0s - loss: 558.5034 - 68ms/epoch - 1ms/step
# Epoch 168/200
# 48/48 - 0s - loss: 544.8282 - 72ms/epoch - 1ms/step
# Epoch 169/200
# 48/48 - 0s - loss: 558.0004 - 71ms/epoch - 1ms/step
# Epoch 170/200
# 48/48 - 0s - loss: 546.1929 - 88ms/epoch - 2ms/step
# Epoch 171/200
# 48/48 - 0s - loss: 549.4052 - 74ms/epoch - 2ms/step
# Epoch 172/200
# 48/48 - 0s - loss: 549.7823 - 75ms/epoch - 2ms/step
# Epoch 173/200
# 48/48 - 0s - loss: 561.0215 - 75ms/epoch - 2ms/step
# Epoch 174/200
# 48/48 - 0s - loss: 547.5735 - 71ms/epoch - 1ms/step
# Epoch 175/200
# 48/48 - 0s - loss: 546.2091 - 75ms/epoch - 2ms/step
# Epoch 176/200
# 48/48 - 0s - loss: 551.5662 - 69ms/epoch - 1ms/step
# Epoch 177/200
# 48/48 - 0s - loss: 542.1829 - 75ms/epoch - 2ms/step
# Epoch 178/200
# 48/48 - 0s - loss: 547.4354 - 71ms/epoch - 1ms/step
# Epoch 179/200
# 48/48 - 0s - loss: 555.7609 - 86ms/epoch - 2ms/step
# Epoch 180/200
# 48/48 - 0s - loss: 556.3282 - 78ms/epoch - 2ms/step
# Epoch 181/200
# 48/48 - 0s - loss: 553.0801 - 74ms/epoch - 2ms/step
# Epoch 182/200
# 48/48 - 0s - loss: 551.3506 - 72ms/epoch - 2ms/step
# Epoch 183/200
# 48/48 - 0s - loss: 551.5367 - 94ms/epoch - 2ms/step
# Epoch 184/200
# 48/48 - 0s - loss: 551.8879 - 85ms/epoch - 2ms/step
# Epoch 185/200
# 48/48 - 0s - loss: 565.1263 - 77ms/epoch - 2ms/step
# Epoch 186/200
# 48/48 - 0s - loss: 560.1667 - 92ms/epoch - 2ms/step
# Epoch 187/200
# 48/48 - 0s - loss: 565.4443 - 75ms/epoch - 2ms/step
# Epoch 188/200
# 48/48 - 0s - loss: 559.3165 - 74ms/epoch - 2ms/step
# Epoch 189/200
# 48/48 - 0s - loss: 546.9235 - 91ms/epoch - 2ms/step
# Epoch 190/200
# 48/48 - 0s - loss: 544.9307 - 85ms/epoch - 2ms/step
# Epoch 191/200
# 48/48 - 0s - loss: 558.6295 - 85ms/epoch - 2ms/step
# Epoch 192/200
# 48/48 - 0s - loss: 546.8533 - 79ms/epoch - 2ms/step
# Epoch 193/200
# 48/48 - 0s - loss: 545.9750 - 83ms/epoch - 2ms/step
# Epoch 194/200
# 48/48 - 0s - loss: 542.9807 - 84ms/epoch - 2ms/step
# Epoch 195/200
# 48/48 - 0s - loss: 553.6006 - 105ms/epoch - 2ms/step
# Epoch 196/200
# 48/48 - 0s - loss: 543.0197 - 96ms/epoch - 2ms/step
# Epoch 197/200
# 48/48 - 0s - loss: 553.6490 - 92ms/epoch - 2ms/step
# Epoch 198/200
# 48/48 - 0s - loss: 566.0416 - 80ms/epoch - 2ms/step
# Epoch 199/200
# 48/48 - 0s - loss: 550.7899 - 84ms/epoch - 2ms/step
# Epoch 200/200
# 48/48 - 0s - loss: 548.0101 - 88ms/epoch - 2ms/step
# Train Score: 538.31 MSE (23.20 RMSE)
# Test Score: 2388.08 MSE (48.87 RMSE)
# 3/3 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 10ms/step

# %%
# Multilayer Perceptron to Predict International Airline Passengers (t+1, given t, t-1, t-2)
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return numpy.array(dataX), numpy.array(dataY)

# fix random seed for reproducibility
numpy.random.seed(7)

# load the dataset
dataframe = read_csv('international-airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# reshape dataset
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# create and fit Multilayer Perceptron model
model = Sequential()
model.add(Dense(12, input_dim=look_back, activation='relu' ))
model.add(Dense(8, activation='relu' ))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam' )
model.fit(trainX, trainY, epochs=400, batch_size=2, verbose=2)

# Estimate model performance
trainScore = model.evaluate(trainX, trainY, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))

# generate predictions for training
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot baseline and predictions
plt.plot(dataset)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/400
# 47/47 - 1s - loss: 1161.9803 - 758ms/epoch - 16ms/step
# Epoch 2/400
# 47/47 - 0s - loss: 903.6833 - 82ms/epoch - 2ms/step
# Epoch 3/400
# 47/47 - 0s - loss: 882.7228 - 78ms/epoch - 2ms/step
# Epoch 4/400
# 47/47 - 0s - loss: 869.8334 - 87ms/epoch - 2ms/step
# Epoch 5/400
# 47/47 - 0s - loss: 932.8081 - 82ms/epoch - 2ms/step
# Epoch 6/400
# 47/47 - 0s - loss: 868.8574 - 78ms/epoch - 2ms/step
# Epoch 7/400
# 47/47 - 0s - loss: 834.8802 - 75ms/epoch - 2ms/step
# Epoch 8/400
# 47/47 - 0s - loss: 849.7213 - 75ms/epoch - 2ms/step
# Epoch 9/400
# 47/47 - 0s - loss: 798.2136 - 81ms/epoch - 2ms/step
# Epoch 10/400
# 47/47 - 0s - loss: 844.5824 - 78ms/epoch - 2ms/step
# Epoch 11/400
# 47/47 - 0s - loss: 776.7761 - 83ms/epoch - 2ms/step
# Epoch 12/400
# 47/47 - 0s - loss: 779.4755 - 86ms/epoch - 2ms/step
# Epoch 13/400
# 47/47 - 0s - loss: 788.7917 - 76ms/epoch - 2ms/step
# Epoch 14/400
# 47/47 - 0s - loss: 794.7643 - 75ms/epoch - 2ms/step
# Epoch 15/400
# 47/47 - 0s - loss: 781.6854 - 81ms/epoch - 2ms/step
# Epoch 16/400
# 47/47 - 0s - loss: 768.3169 - 76ms/epoch - 2ms/step
# Epoch 17/400
# 47/47 - 0s - loss: 738.8580 - 82ms/epoch - 2ms/step
# Epoch 18/400
# 47/47 - 0s - loss: 693.0126 - 75ms/epoch - 2ms/step
# Epoch 19/400
# 47/47 - 0s - loss: 713.6902 - 77ms/epoch - 2ms/step
# Epoch 20/400
# 47/47 - 0s - loss: 701.7515 - 74ms/epoch - 2ms/step
# Epoch 21/400
# 47/47 - 0s - loss: 697.1817 - 79ms/epoch - 2ms/step
# Epoch 22/400
# 47/47 - 0s - loss: 682.3359 - 84ms/epoch - 2ms/step
# Epoch 23/400
# 47/47 - 0s - loss: 661.0669 - 89ms/epoch - 2ms/step
# Epoch 24/400
# 47/47 - 0s - loss: 673.4897 - 101ms/epoch - 2ms/step
# Epoch 25/400
# 47/47 - 0s - loss: 646.7257 - 98ms/epoch - 2ms/step
# Epoch 26/400
# 47/47 - 0s - loss: 642.7246 - 87ms/epoch - 2ms/step
# Epoch 27/400
# 47/47 - 0s - loss: 661.7936 - 82ms/epoch - 2ms/step
# Epoch 28/400
# 47/47 - 0s - loss: 634.6857 - 78ms/epoch - 2ms/step
# Epoch 29/400
# 47/47 - 0s - loss: 641.0555 - 76ms/epoch - 2ms/step
# Epoch 30/400
# 47/47 - 0s - loss: 674.4314 - 71ms/epoch - 2ms/step
# Epoch 31/400
# 47/47 - 0s - loss: 697.8560 - 77ms/epoch - 2ms/step
# Epoch 32/400
# 47/47 - 0s - loss: 620.0176 - 79ms/epoch - 2ms/step
# Epoch 33/400
# 47/47 - 0s - loss: 594.1474 - 77ms/epoch - 2ms/step
# Epoch 34/400
# 47/47 - 0s - loss: 555.3678 - 77ms/epoch - 2ms/step
# Epoch 35/400
# 47/47 - 0s - loss: 580.3772 - 79ms/epoch - 2ms/step
# Epoch 36/400
# 47/47 - 0s - loss: 580.0206 - 82ms/epoch - 2ms/step
# Epoch 37/400
# 47/47 - 0s - loss: 578.7418 - 73ms/epoch - 2ms/step
# Epoch 38/400
# 47/47 - 0s - loss: 593.5987 - 75ms/epoch - 2ms/step
# Epoch 39/400
# 47/47 - 0s - loss: 600.2180 - 82ms/epoch - 2ms/step
# Epoch 40/400
# 47/47 - 0s - loss: 558.7292 - 74ms/epoch - 2ms/step
# Epoch 41/400
# 47/47 - 0s - loss: 555.8708 - 73ms/epoch - 2ms/step
# Epoch 42/400
# 47/47 - 0s - loss: 545.5321 - 79ms/epoch - 2ms/step
# Epoch 43/400
# 47/47 - 0s - loss: 551.4670 - 75ms/epoch - 2ms/step
# Epoch 44/400
# 47/47 - 0s - loss: 546.0731 - 75ms/epoch - 2ms/step
# Epoch 45/400
# 47/47 - 0s - loss: 559.2435 - 81ms/epoch - 2ms/step
# Epoch 46/400
# 47/47 - 0s - loss: 540.7891 - 86ms/epoch - 2ms/step
# Epoch 47/400
# 47/47 - 0s - loss: 528.5258 - 75ms/epoch - 2ms/step
# Epoch 48/400
# 47/47 - 0s - loss: 533.4784 - 76ms/epoch - 2ms/step
# Epoch 49/400
# 47/47 - 0s - loss: 558.3572 - 88ms/epoch - 2ms/step
# Epoch 50/400
# 47/47 - 0s - loss: 552.3247 - 80ms/epoch - 2ms/step
# Epoch 51/400
# 47/47 - 0s - loss: 623.4418 - 73ms/epoch - 2ms/step
# Epoch 52/400
# 47/47 - 0s - loss: 529.7106 - 83ms/epoch - 2ms/step
# Epoch 53/400
# 47/47 - 0s - loss: 545.9220 - 76ms/epoch - 2ms/step
# Epoch 54/400
# 47/47 - 0s - loss: 516.7606 - 74ms/epoch - 2ms/step
# Epoch 55/400
# 47/47 - 0s - loss: 526.8683 - 77ms/epoch - 2ms/step
# Epoch 56/400
# 47/47 - 0s - loss: 512.3755 - 74ms/epoch - 2ms/step
# Epoch 57/400
# 47/47 - 0s - loss: 518.3679 - 80ms/epoch - 2ms/step
# Epoch 58/400
# 47/47 - 0s - loss: 520.4880 - 81ms/epoch - 2ms/step
# Epoch 59/400
# 47/47 - 0s - loss: 513.1888 - 80ms/epoch - 2ms/step
# Epoch 60/400
# 47/47 - 0s - loss: 510.8406 - 73ms/epoch - 2ms/step
# Epoch 61/400
# 47/47 - 0s - loss: 535.9320 - 83ms/epoch - 2ms/step
# Epoch 62/400
# 47/47 - 0s - loss: 544.4088 - 78ms/epoch - 2ms/step
# Epoch 63/400
# 47/47 - 0s - loss: 522.9589 - 77ms/epoch - 2ms/step
# Epoch 64/400
# 47/47 - 0s - loss: 510.9808 - 73ms/epoch - 2ms/step
# Epoch 65/400
# 47/47 - 0s - loss: 510.7253 - 73ms/epoch - 2ms/step
# Epoch 66/400
# 47/47 - 0s - loss: 524.7615 - 74ms/epoch - 2ms/step
# Epoch 67/400
# 47/47 - 0s - loss: 520.5650 - 79ms/epoch - 2ms/step
# Epoch 68/400
# 47/47 - 0s - loss: 525.7457 - 82ms/epoch - 2ms/step
# Epoch 69/400
# 47/47 - 0s - loss: 494.6197 - 88ms/epoch - 2ms/step
# Epoch 70/400
# 47/47 - 0s - loss: 533.2512 - 78ms/epoch - 2ms/step
# Epoch 71/400
# 47/47 - 0s - loss: 534.3061 - 92ms/epoch - 2ms/step
# Epoch 72/400
# 47/47 - 0s - loss: 500.5586 - 80ms/epoch - 2ms/step
# Epoch 73/400
# 47/47 - 0s - loss: 509.7780 - 69ms/epoch - 1ms/step
# Epoch 74/400
# 47/47 - 0s - loss: 524.0766 - 87ms/epoch - 2ms/step
# Epoch 75/400
# 47/47 - 0s - loss: 561.7313 - 73ms/epoch - 2ms/step
# Epoch 76/400
# 47/47 - 0s - loss: 559.2079 - 79ms/epoch - 2ms/step
# Epoch 77/400
# 47/47 - 0s - loss: 496.4997 - 83ms/epoch - 2ms/step
# Epoch 78/400
# 47/47 - 0s - loss: 492.7913 - 73ms/epoch - 2ms/step
# Epoch 79/400
# 47/47 - 0s - loss: 504.7418 - 80ms/epoch - 2ms/step
# Epoch 80/400
# 47/47 - 0s - loss: 533.0585 - 80ms/epoch - 2ms/step
# Epoch 81/400
# 47/47 - 0s - loss: 549.4982 - 80ms/epoch - 2ms/step
# Epoch 82/400
# 47/47 - 0s - loss: 498.7999 - 82ms/epoch - 2ms/step
# Epoch 83/400
# 47/47 - 0s - loss: 580.9937 - 80ms/epoch - 2ms/step
# Epoch 84/400
# 47/47 - 0s - loss: 529.7689 - 78ms/epoch - 2ms/step
# Epoch 85/400
# 47/47 - 0s - loss: 520.6357 - 80ms/epoch - 2ms/step
# Epoch 86/400
# 47/47 - 0s - loss: 558.9634 - 86ms/epoch - 2ms/step
# Epoch 87/400
# 47/47 - 0s - loss: 519.4456 - 76ms/epoch - 2ms/step
# Epoch 88/400
# 47/47 - 0s - loss: 488.7486 - 87ms/epoch - 2ms/step
# Epoch 89/400
# 47/47 - 0s - loss: 514.0576 - 79ms/epoch - 2ms/step
# Epoch 90/400
# 47/47 - 0s - loss: 498.3031 - 78ms/epoch - 2ms/step
# Epoch 91/400
# 47/47 - 0s - loss: 507.5828 - 81ms/epoch - 2ms/step
# Epoch 92/400
# 47/47 - 0s - loss: 573.8379 - 77ms/epoch - 2ms/step
# Epoch 93/400
# 47/47 - 0s - loss: 503.7795 - 73ms/epoch - 2ms/step
# Epoch 94/400
# 47/47 - 0s - loss: 522.1628 - 82ms/epoch - 2ms/step
# Epoch 95/400
# 47/47 - 0s - loss: 509.9935 - 77ms/epoch - 2ms/step
# Epoch 96/400
# 47/47 - 0s - loss: 520.3693 - 91ms/epoch - 2ms/step
# Epoch 97/400
# 47/47 - 0s - loss: 512.0383 - 81ms/epoch - 2ms/step
# Epoch 98/400
# 47/47 - 0s - loss: 500.8154 - 85ms/epoch - 2ms/step
# Epoch 99/400
# 47/47 - 0s - loss: 514.9591 - 72ms/epoch - 2ms/step
# Epoch 100/400
# 47/47 - 0s - loss: 527.1305 - 74ms/epoch - 2ms/step
# Epoch 101/400
# 47/47 - 0s - loss: 567.4388 - 87ms/epoch - 2ms/step
# Epoch 102/400
# 47/47 - 0s - loss: 541.1165 - 73ms/epoch - 2ms/step
# Epoch 103/400
# 47/47 - 0s - loss: 539.7946 - 74ms/epoch - 2ms/step
# Epoch 104/400
# 47/47 - 0s - loss: 504.0326 - 75ms/epoch - 2ms/step
# Epoch 105/400
# 47/47 - 0s - loss: 526.9260 - 72ms/epoch - 2ms/step
# Epoch 106/400
# 47/47 - 0s - loss: 500.4529 - 72ms/epoch - 2ms/step
# Epoch 107/400
# 47/47 - 0s - loss: 520.4902 - 87ms/epoch - 2ms/step
# Epoch 108/400
# 47/47 - 0s - loss: 556.8654 - 75ms/epoch - 2ms/step
# Epoch 109/400
# 47/47 - 0s - loss: 499.3549 - 70ms/epoch - 1ms/step
# Epoch 110/400
# 47/47 - 0s - loss: 507.4655 - 72ms/epoch - 2ms/step
# Epoch 111/400
# 47/47 - 0s - loss: 501.4833 - 121ms/epoch - 3ms/step
# Epoch 112/400
# 47/47 - 0s - loss: 524.6679 - 116ms/epoch - 2ms/step
# Epoch 113/400
# 47/47 - 0s - loss: 512.4236 - 122ms/epoch - 3ms/step
# Epoch 114/400
# 47/47 - 0s - loss: 528.1907 - 123ms/epoch - 3ms/step
# Epoch 115/400
# 47/47 - 0s - loss: 526.3667 - 107ms/epoch - 2ms/step
# Epoch 116/400
# 47/47 - 0s - loss: 514.9366 - 108ms/epoch - 2ms/step
# Epoch 117/400
# 47/47 - 0s - loss: 501.6577 - 105ms/epoch - 2ms/step
# Epoch 118/400
# 47/47 - 0s - loss: 490.1213 - 101ms/epoch - 2ms/step
# Epoch 119/400
# 47/47 - 0s - loss: 502.1581 - 129ms/epoch - 3ms/step
# Epoch 120/400
# 47/47 - 0s - loss: 537.8170 - 127ms/epoch - 3ms/step
# Epoch 121/400
# 47/47 - 0s - loss: 498.5048 - 96ms/epoch - 2ms/step
# Epoch 122/400
# 47/47 - 0s - loss: 487.9857 - 104ms/epoch - 2ms/step
# Epoch 123/400
# 47/47 - 0s - loss: 510.1793 - 105ms/epoch - 2ms/step
# Epoch 124/400
# 47/47 - 0s - loss: 579.3196 - 98ms/epoch - 2ms/step
# Epoch 125/400
# 47/47 - 0s - loss: 519.6035 - 110ms/epoch - 2ms/step
# Epoch 126/400
# 47/47 - 0s - loss: 536.0525 - 121ms/epoch - 3ms/step
# Epoch 127/400
# 47/47 - 0s - loss: 499.1942 - 110ms/epoch - 2ms/step
# Epoch 128/400
# 47/47 - 0s - loss: 519.7901 - 103ms/epoch - 2ms/step
# Epoch 129/400
# 47/47 - 0s - loss: 496.7887 - 130ms/epoch - 3ms/step
# Epoch 130/400
# 47/47 - 0s - loss: 500.2364 - 129ms/epoch - 3ms/step
# Epoch 131/400
# 47/47 - 0s - loss: 531.9418 - 117ms/epoch - 2ms/step
# Epoch 132/400
# 47/47 - 0s - loss: 489.8669 - 114ms/epoch - 2ms/step
# Epoch 133/400
# 47/47 - 0s - loss: 516.0947 - 112ms/epoch - 2ms/step
# Epoch 134/400
# 47/47 - 0s - loss: 498.6671 - 143ms/epoch - 3ms/step
# Epoch 135/400
# 47/47 - 0s - loss: 504.7989 - 117ms/epoch - 2ms/step
# Epoch 136/400
# 47/47 - 0s - loss: 552.4196 - 127ms/epoch - 3ms/step
# Epoch 137/400
# 47/47 - 0s - loss: 501.6414 - 134ms/epoch - 3ms/step
# Epoch 138/400
# 47/47 - 0s - loss: 533.4615 - 79ms/epoch - 2ms/step
# Epoch 139/400
# 47/47 - 0s - loss: 510.0747 - 79ms/epoch - 2ms/step
# Epoch 140/400
# 47/47 - 0s - loss: 510.0217 - 79ms/epoch - 2ms/step
# Epoch 141/400
# 47/47 - 0s - loss: 546.1932 - 74ms/epoch - 2ms/step
# Epoch 142/400
# 47/47 - 0s - loss: 503.1894 - 76ms/epoch - 2ms/step
# Epoch 143/400
# 47/47 - 0s - loss: 504.9225 - 87ms/epoch - 2ms/step
# Epoch 144/400
# 47/47 - 0s - loss: 537.3006 - 74ms/epoch - 2ms/step
# Epoch 145/400
# 47/47 - 0s - loss: 490.6605 - 73ms/epoch - 2ms/step
# Epoch 146/400
# 47/47 - 0s - loss: 518.4373 - 75ms/epoch - 2ms/step
# Epoch 147/400
# 47/47 - 0s - loss: 558.2689 - 82ms/epoch - 2ms/step
# Epoch 148/400
# 47/47 - 0s - loss: 493.5507 - 74ms/epoch - 2ms/step
# Epoch 149/400
# 47/47 - 0s - loss: 484.3158 - 81ms/epoch - 2ms/step
# Epoch 150/400
# 47/47 - 0s - loss: 576.3079 - 89ms/epoch - 2ms/step
# Epoch 151/400
# 47/47 - 0s - loss: 563.5653 - 85ms/epoch - 2ms/step
# Epoch 152/400
# 47/47 - 0s - loss: 538.5638 - 84ms/epoch - 2ms/step
# Epoch 153/400
# 47/47 - 0s - loss: 510.1718 - 79ms/epoch - 2ms/step
# Epoch 154/400
# 47/47 - 0s - loss: 504.6489 - 83ms/epoch - 2ms/step
# Epoch 155/400
# 47/47 - 0s - loss: 493.1909 - 80ms/epoch - 2ms/step
# Epoch 156/400
# 47/47 - 0s - loss: 499.7004 - 92ms/epoch - 2ms/step
# Epoch 157/400
# 47/47 - 0s - loss: 512.3096 - 82ms/epoch - 2ms/step
# Epoch 158/400
# 47/47 - 0s - loss: 506.7007 - 76ms/epoch - 2ms/step
# Epoch 159/400
# 47/47 - 0s - loss: 496.3997 - 77ms/epoch - 2ms/step
# Epoch 160/400
# 47/47 - 0s - loss: 523.4532 - 85ms/epoch - 2ms/step
# Epoch 161/400
# 47/47 - 0s - loss: 519.3437 - 95ms/epoch - 2ms/step
# Epoch 162/400
# 47/47 - 0s - loss: 513.0607 - 93ms/epoch - 2ms/step
# Epoch 163/400
# 47/47 - 0s - loss: 503.0374 - 79ms/epoch - 2ms/step
# Epoch 164/400
# 47/47 - 0s - loss: 498.1837 - 85ms/epoch - 2ms/step
# Epoch 165/400
# 47/47 - 0s - loss: 501.7243 - 84ms/epoch - 2ms/step
# Epoch 166/400
# 47/47 - 0s - loss: 552.0552 - 76ms/epoch - 2ms/step
# Epoch 167/400
# 47/47 - 0s - loss: 544.2084 - 91ms/epoch - 2ms/step
# Epoch 168/400
# 47/47 - 0s - loss: 516.0737 - 74ms/epoch - 2ms/step
# Epoch 169/400
# 47/47 - 0s - loss: 500.7870 - 72ms/epoch - 2ms/step
# Epoch 170/400
# 47/47 - 0s - loss: 519.1949 - 82ms/epoch - 2ms/step
# Epoch 171/400
# 47/47 - 0s - loss: 544.4295 - 84ms/epoch - 2ms/step
# Epoch 172/400
# 47/47 - 0s - loss: 502.6613 - 80ms/epoch - 2ms/step
# Epoch 173/400
# 47/47 - 0s - loss: 520.6400 - 82ms/epoch - 2ms/step
# Epoch 174/400
# 47/47 - 0s - loss: 502.7776 - 77ms/epoch - 2ms/step
# Epoch 175/400
# 47/47 - 0s - loss: 521.2338 - 78ms/epoch - 2ms/step
# Epoch 176/400
# 47/47 - 0s - loss: 511.5174 - 76ms/epoch - 2ms/step
# Epoch 177/400
# 47/47 - 0s - loss: 513.4364 - 76ms/epoch - 2ms/step
# Epoch 178/400
# 47/47 - 0s - loss: 500.0292 - 80ms/epoch - 2ms/step
# Epoch 179/400
# 47/47 - 0s - loss: 527.6342 - 85ms/epoch - 2ms/step
# Epoch 180/400
# 47/47 - 0s - loss: 486.2725 - 77ms/epoch - 2ms/step
# Epoch 181/400
# 47/47 - 0s - loss: 506.5884 - 74ms/epoch - 2ms/step
# Epoch 182/400
# 47/47 - 0s - loss: 519.0271 - 78ms/epoch - 2ms/step
# Epoch 183/400
# 47/47 - 0s - loss: 508.6155 - 79ms/epoch - 2ms/step
# Epoch 184/400
# 47/47 - 0s - loss: 492.7646 - 77ms/epoch - 2ms/step
# Epoch 185/400
# 47/47 - 0s - loss: 494.7969 - 71ms/epoch - 2ms/step
# Epoch 186/400
# 47/47 - 0s - loss: 497.6309 - 86ms/epoch - 2ms/step
# Epoch 187/400
# 47/47 - 0s - loss: 495.2216 - 79ms/epoch - 2ms/step
# Epoch 188/400
# 47/47 - 0s - loss: 497.8670 - 95ms/epoch - 2ms/step
# Epoch 189/400
# 47/47 - 0s - loss: 506.2201 - 82ms/epoch - 2ms/step
# Epoch 190/400
# 47/47 - 0s - loss: 504.5828 - 80ms/epoch - 2ms/step
# Epoch 191/400
# 47/47 - 0s - loss: 533.9315 - 86ms/epoch - 2ms/step
# Epoch 192/400
# 47/47 - 0s - loss: 494.2733 - 81ms/epoch - 2ms/step
# Epoch 193/400
# 47/47 - 0s - loss: 495.3742 - 82ms/epoch - 2ms/step
# Epoch 194/400
# 47/47 - 0s - loss: 500.6797 - 75ms/epoch - 2ms/step
# Epoch 195/400
# 47/47 - 0s - loss: 516.3533 - 81ms/epoch - 2ms/step
# Epoch 196/400
# 47/47 - 0s - loss: 499.4477 - 78ms/epoch - 2ms/step
# Epoch 197/400
# 47/47 - 0s - loss: 489.9403 - 77ms/epoch - 2ms/step
# Epoch 198/400
# 47/47 - 0s - loss: 508.7918 - 94ms/epoch - 2ms/step
# Epoch 199/400
# 47/47 - 0s - loss: 504.8103 - 74ms/epoch - 2ms/step
# Epoch 200/400
# 47/47 - 0s - loss: 494.1703 - 73ms/epoch - 2ms/step
# Epoch 201/400
# 47/47 - 0s - loss: 512.7564 - 71ms/epoch - 2ms/step
# Epoch 202/400
# 47/47 - 0s - loss: 509.0731 - 76ms/epoch - 2ms/step
# Epoch 203/400
# 47/47 - 0s - loss: 491.6315 - 81ms/epoch - 2ms/step
# Epoch 204/400
# 47/47 - 0s - loss: 494.6030 - 72ms/epoch - 2ms/step
# Epoch 205/400
# 47/47 - 0s - loss: 514.4723 - 78ms/epoch - 2ms/step
# Epoch 206/400
# 47/47 - 0s - loss: 512.6251 - 75ms/epoch - 2ms/step
# Epoch 207/400
# 47/47 - 0s - loss: 510.2484 - 90ms/epoch - 2ms/step
# Epoch 208/400
# 47/47 - 0s - loss: 523.6758 - 93ms/epoch - 2ms/step
# Epoch 209/400
# 47/47 - 0s - loss: 510.3961 - 83ms/epoch - 2ms/step
# Epoch 210/400
# 47/47 - 0s - loss: 500.2249 - 90ms/epoch - 2ms/step
# Epoch 211/400
# 47/47 - 0s - loss: 498.7704 - 86ms/epoch - 2ms/step
# Epoch 212/400
# 47/47 - 0s - loss: 540.0266 - 84ms/epoch - 2ms/step
# Epoch 213/400
# 47/47 - 0s - loss: 513.4187 - 75ms/epoch - 2ms/step
# Epoch 214/400
# 47/47 - 0s - loss: 492.4730 - 80ms/epoch - 2ms/step
# Epoch 215/400
# 47/47 - 0s - loss: 558.6537 - 85ms/epoch - 2ms/step
# Epoch 216/400
# 47/47 - 0s - loss: 491.1489 - 77ms/epoch - 2ms/step
# Epoch 217/400
# 47/47 - 0s - loss: 515.5774 - 72ms/epoch - 2ms/step
# Epoch 218/400
# 47/47 - 0s - loss: 502.5958 - 75ms/epoch - 2ms/step
# Epoch 219/400
# 47/47 - 0s - loss: 487.1425 - 81ms/epoch - 2ms/step
# Epoch 220/400
# 47/47 - 0s - loss: 508.8897 - 76ms/epoch - 2ms/step
# Epoch 221/400
# 47/47 - 0s - loss: 486.8486 - 73ms/epoch - 2ms/step
# Epoch 222/400
# 47/47 - 0s - loss: 500.2208 - 74ms/epoch - 2ms/step
# Epoch 223/400
# 47/47 - 0s - loss: 491.1666 - 95ms/epoch - 2ms/step
# Epoch 224/400
# 47/47 - 0s - loss: 518.2368 - 74ms/epoch - 2ms/step
# Epoch 225/400
# 47/47 - 0s - loss: 508.3441 - 79ms/epoch - 2ms/step
# Epoch 226/400
# 47/47 - 0s - loss: 529.6938 - 82ms/epoch - 2ms/step
# Epoch 227/400
# 47/47 - 0s - loss: 561.6515 - 86ms/epoch - 2ms/step
# Epoch 228/400
# 47/47 - 0s - loss: 523.1597 - 76ms/epoch - 2ms/step
# Epoch 229/400
# 47/47 - 0s - loss: 512.0410 - 81ms/epoch - 2ms/step
# Epoch 230/400
# 47/47 - 0s - loss: 498.3259 - 76ms/epoch - 2ms/step
# Epoch 231/400
# 47/47 - 0s - loss: 500.7437 - 77ms/epoch - 2ms/step
# Epoch 232/400
# 47/47 - 0s - loss: 494.0091 - 77ms/epoch - 2ms/step
# Epoch 233/400
# 47/47 - 0s - loss: 510.9517 - 77ms/epoch - 2ms/step
# Epoch 234/400
# 47/47 - 0s - loss: 518.0413 - 74ms/epoch - 2ms/step
# Epoch 235/400
# 47/47 - 0s - loss: 511.0442 - 72ms/epoch - 2ms/step
# Epoch 236/400
# 47/47 - 0s - loss: 501.9046 - 85ms/epoch - 2ms/step
# Epoch 237/400
# 47/47 - 0s - loss: 509.0324 - 72ms/epoch - 2ms/step
# Epoch 238/400
# 47/47 - 0s - loss: 517.6617 - 87ms/epoch - 2ms/step
# Epoch 239/400
# 47/47 - 0s - loss: 487.9581 - 82ms/epoch - 2ms/step
# Epoch 240/400
# 47/47 - 0s - loss: 486.8245 - 78ms/epoch - 2ms/step
# Epoch 241/400
# 47/47 - 0s - loss: 494.8270 - 74ms/epoch - 2ms/step
# Epoch 242/400
# 47/47 - 0s - loss: 492.2553 - 76ms/epoch - 2ms/step
# Epoch 243/400
# 47/47 - 0s - loss: 483.2653 - 81ms/epoch - 2ms/step
# Epoch 244/400
# 47/47 - 0s - loss: 490.2948 - 75ms/epoch - 2ms/step
# Epoch 245/400
# 47/47 - 0s - loss: 546.8004 - 74ms/epoch - 2ms/step
# Epoch 246/400
# 47/47 - 0s - loss: 496.4352 - 71ms/epoch - 2ms/step
# Epoch 247/400
# 47/47 - 0s - loss: 494.4263 - 70ms/epoch - 1ms/step
# Epoch 248/400
# 47/47 - 0s - loss: 533.1259 - 91ms/epoch - 2ms/step
# Epoch 249/400
# 47/47 - 0s - loss: 503.4588 - 81ms/epoch - 2ms/step
# Epoch 250/400
# 47/47 - 0s - loss: 498.4775 - 77ms/epoch - 2ms/step
# Epoch 251/400
# 47/47 - 0s - loss: 486.8469 - 81ms/epoch - 2ms/step
# Epoch 252/400
# 47/47 - 0s - loss: 509.1491 - 80ms/epoch - 2ms/step
# Epoch 253/400
# 47/47 - 0s - loss: 501.7902 - 76ms/epoch - 2ms/step
# Epoch 254/400
# 47/47 - 0s - loss: 512.0714 - 76ms/epoch - 2ms/step
# Epoch 255/400
# 47/47 - 0s - loss: 528.8176 - 77ms/epoch - 2ms/step
# Epoch 256/400
# 47/47 - 0s - loss: 461.5902 - 72ms/epoch - 2ms/step
# Epoch 257/400
# 47/47 - 0s - loss: 537.4510 - 84ms/epoch - 2ms/step
# Epoch 258/400
# 47/47 - 0s - loss: 506.2306 - 132ms/epoch - 3ms/step
# Epoch 259/400
# 47/47 - 0s - loss: 543.5438 - 120ms/epoch - 3ms/step
# Epoch 260/400
# 47/47 - 0s - loss: 501.3638 - 136ms/epoch - 3ms/step
# Epoch 261/400
# 47/47 - 0s - loss: 473.0883 - 120ms/epoch - 3ms/step
# Epoch 262/400
# 47/47 - 0s - loss: 565.2007 - 117ms/epoch - 2ms/step
# Epoch 263/400
# 47/47 - 0s - loss: 493.4542 - 115ms/epoch - 2ms/step
# Epoch 264/400
# 47/47 - 0s - loss: 481.6668 - 117ms/epoch - 2ms/step
# Epoch 265/400
# 47/47 - 0s - loss: 503.6988 - 118ms/epoch - 3ms/step
# Epoch 266/400
# 47/47 - 0s - loss: 500.8834 - 109ms/epoch - 2ms/step
# Epoch 267/400
# 47/47 - 0s - loss: 457.0981 - 110ms/epoch - 2ms/step
# Epoch 268/400
# 47/47 - 0s - loss: 521.3729 - 125ms/epoch - 3ms/step
# Epoch 269/400
# 47/47 - 0s - loss: 484.3593 - 138ms/epoch - 3ms/step
# Epoch 270/400
# 47/47 - 0s - loss: 503.5010 - 136ms/epoch - 3ms/step
# Epoch 271/400
# 47/47 - 0s - loss: 512.7412 - 125ms/epoch - 3ms/step
# Epoch 272/400
# 47/47 - 0s - loss: 486.6939 - 131ms/epoch - 3ms/step
# Epoch 273/400
# 47/47 - 0s - loss: 485.8569 - 119ms/epoch - 3ms/step
# Epoch 274/400
# 47/47 - 0s - loss: 489.5256 - 114ms/epoch - 2ms/step
# Epoch 275/400
# 47/47 - 0s - loss: 502.5409 - 134ms/epoch - 3ms/step
# Epoch 276/400
# 47/47 - 0s - loss: 502.1232 - 120ms/epoch - 3ms/step
# Epoch 277/400
# 47/47 - 0s - loss: 489.5278 - 139ms/epoch - 3ms/step
# Epoch 278/400
# 47/47 - 0s - loss: 507.6933 - 121ms/epoch - 3ms/step
# Epoch 279/400
# 47/47 - 0s - loss: 491.9409 - 124ms/epoch - 3ms/step
# Epoch 280/400
# 47/47 - 0s - loss: 489.5602 - 135ms/epoch - 3ms/step
# Epoch 281/400
# 47/47 - 0s - loss: 485.3182 - 122ms/epoch - 3ms/step
# Epoch 282/400
# 47/47 - 0s - loss: 483.4816 - 125ms/epoch - 3ms/step
# Epoch 283/400
# 47/47 - 0s - loss: 484.2622 - 142ms/epoch - 3ms/step
# Epoch 284/400
# 47/47 - 0s - loss: 485.7531 - 136ms/epoch - 3ms/step
# Epoch 285/400
# 47/47 - 0s - loss: 498.6218 - 93ms/epoch - 2ms/step
# Epoch 286/400
# 47/47 - 0s - loss: 497.3906 - 72ms/epoch - 2ms/step
# Epoch 287/400
# 47/47 - 0s - loss: 515.8918 - 76ms/epoch - 2ms/step
# Epoch 288/400
# 47/47 - 0s - loss: 529.7945 - 77ms/epoch - 2ms/step
# Epoch 289/400
# 47/47 - 0s - loss: 518.9441 - 91ms/epoch - 2ms/step
# Epoch 290/400
# 47/47 - 0s - loss: 476.6005 - 82ms/epoch - 2ms/step
# Epoch 291/400
# 47/47 - 0s - loss: 504.7269 - 86ms/epoch - 2ms/step
# Epoch 292/400
# 47/47 - 0s - loss: 515.6229 - 72ms/epoch - 2ms/step
# Epoch 293/400
# 47/47 - 0s - loss: 488.5495 - 76ms/epoch - 2ms/step
# Epoch 294/400
# 47/47 - 0s - loss: 484.6097 - 79ms/epoch - 2ms/step
# Epoch 295/400
# 47/47 - 0s - loss: 474.2393 - 72ms/epoch - 2ms/step
# Epoch 296/400
# 47/47 - 0s - loss: 510.8413 - 87ms/epoch - 2ms/step
# Epoch 297/400
# 47/47 - 0s - loss: 497.3060 - 100ms/epoch - 2ms/step
# Epoch 298/400
# 47/47 - 0s - loss: 470.0735 - 71ms/epoch - 2ms/step
# Epoch 299/400
# 47/47 - 0s - loss: 487.0162 - 70ms/epoch - 1ms/step
# Epoch 300/400
# 47/47 - 0s - loss: 476.7237 - 75ms/epoch - 2ms/step
# Epoch 301/400
# 47/47 - 0s - loss: 467.2220 - 73ms/epoch - 2ms/step
# Epoch 302/400
# 47/47 - 0s - loss: 512.9719 - 76ms/epoch - 2ms/step
# Epoch 303/400
# 47/47 - 0s - loss: 484.1279 - 73ms/epoch - 2ms/step
# Epoch 304/400
# 47/47 - 0s - loss: 529.9174 - 71ms/epoch - 2ms/step
# Epoch 305/400
# 47/47 - 0s - loss: 466.2183 - 71ms/epoch - 2ms/step
# Epoch 306/400
# 47/47 - 0s - loss: 485.2216 - 79ms/epoch - 2ms/step
# Epoch 307/400
# 47/47 - 0s - loss: 488.0821 - 81ms/epoch - 2ms/step
# Epoch 308/400
# 47/47 - 0s - loss: 473.5030 - 72ms/epoch - 2ms/step
# Epoch 309/400
# 47/47 - 0s - loss: 472.3549 - 73ms/epoch - 2ms/step
# Epoch 310/400
# 47/47 - 0s - loss: 496.1023 - 95ms/epoch - 2ms/step
# Epoch 311/400
# 47/47 - 0s - loss: 483.4623 - 73ms/epoch - 2ms/step
# Epoch 312/400
# 47/47 - 0s - loss: 512.1348 - 76ms/epoch - 2ms/step
# Epoch 313/400
# 47/47 - 0s - loss: 494.2859 - 76ms/epoch - 2ms/step
# Epoch 314/400
# 47/47 - 0s - loss: 528.1199 - 76ms/epoch - 2ms/step
# Epoch 315/400
# 47/47 - 0s - loss: 500.8378 - 85ms/epoch - 2ms/step
# Epoch 316/400
# 47/47 - 0s - loss: 470.4265 - 74ms/epoch - 2ms/step
# Epoch 317/400
# 47/47 - 0s - loss: 520.6265 - 79ms/epoch - 2ms/step
# Epoch 318/400
# 47/47 - 0s - loss: 470.5852 - 79ms/epoch - 2ms/step
# Epoch 319/400
# 47/47 - 0s - loss: 487.6247 - 77ms/epoch - 2ms/step
# Epoch 320/400
# 47/47 - 0s - loss: 500.4257 - 85ms/epoch - 2ms/step
# Epoch 321/400
# 47/47 - 0s - loss: 477.3129 - 74ms/epoch - 2ms/step
# Epoch 322/400
# 47/47 - 0s - loss: 502.8269 - 81ms/epoch - 2ms/step
# Epoch 323/400
# 47/47 - 0s - loss: 482.4698 - 82ms/epoch - 2ms/step
# Epoch 324/400
# 47/47 - 0s - loss: 518.7805 - 72ms/epoch - 2ms/step
# Epoch 325/400
# 47/47 - 0s - loss: 484.1649 - 82ms/epoch - 2ms/step
# Epoch 326/400
# 47/47 - 0s - loss: 477.7529 - 74ms/epoch - 2ms/step
# Epoch 327/400
# 47/47 - 0s - loss: 507.8121 - 75ms/epoch - 2ms/step
# Epoch 328/400
# 47/47 - 0s - loss: 521.6445 - 86ms/epoch - 2ms/step
# Epoch 329/400
# 47/47 - 0s - loss: 467.8588 - 73ms/epoch - 2ms/step
# Epoch 330/400
# 47/47 - 0s - loss: 483.2295 - 78ms/epoch - 2ms/step
# Epoch 331/400
# 47/47 - 0s - loss: 494.2724 - 84ms/epoch - 2ms/step
# Epoch 332/400
# 47/47 - 0s - loss: 486.9076 - 74ms/epoch - 2ms/step
# Epoch 333/400
# 47/47 - 0s - loss: 496.3268 - 74ms/epoch - 2ms/step
# Epoch 334/400
# 47/47 - 0s - loss: 480.5207 - 78ms/epoch - 2ms/step
# Epoch 335/400
# 47/47 - 0s - loss: 497.7743 - 93ms/epoch - 2ms/step
# Epoch 336/400
# 47/47 - 0s - loss: 480.1750 - 72ms/epoch - 2ms/step
# Epoch 337/400
# 47/47 - 0s - loss: 481.6374 - 73ms/epoch - 2ms/step
# Epoch 338/400
# 47/47 - 0s - loss: 465.5698 - 73ms/epoch - 2ms/step
# Epoch 339/400
# 47/47 - 0s - loss: 499.5814 - 77ms/epoch - 2ms/step
# Epoch 340/400
# 47/47 - 0s - loss: 489.9858 - 77ms/epoch - 2ms/step
# Epoch 341/400
# 47/47 - 0s - loss: 467.2827 - 74ms/epoch - 2ms/step
# Epoch 342/400
# 47/47 - 0s - loss: 489.2032 - 74ms/epoch - 2ms/step
# Epoch 343/400
# 47/47 - 0s - loss: 490.5930 - 79ms/epoch - 2ms/step
# Epoch 344/400
# 47/47 - 0s - loss: 501.5220 - 85ms/epoch - 2ms/step
# Epoch 345/400
# 47/47 - 0s - loss: 473.3942 - 77ms/epoch - 2ms/step
# Epoch 346/400
# 47/47 - 0s - loss: 479.3131 - 83ms/epoch - 2ms/step
# Epoch 347/400
# 47/47 - 0s - loss: 470.0964 - 81ms/epoch - 2ms/step
# Epoch 348/400
# 47/47 - 0s - loss: 484.4225 - 92ms/epoch - 2ms/step
# Epoch 349/400
# 47/47 - 0s - loss: 500.0869 - 75ms/epoch - 2ms/step
# Epoch 350/400
# 47/47 - 0s - loss: 463.5789 - 75ms/epoch - 2ms/step
# Epoch 351/400
# 47/47 - 0s - loss: 508.8920 - 80ms/epoch - 2ms/step
# Epoch 352/400
# 47/47 - 0s - loss: 503.9304 - 72ms/epoch - 2ms/step
# Epoch 353/400
# 47/47 - 0s - loss: 479.4805 - 72ms/epoch - 2ms/step
# Epoch 354/400
# 47/47 - 0s - loss: 487.3306 - 77ms/epoch - 2ms/step
# Epoch 355/400
# 47/47 - 0s - loss: 485.6216 - 75ms/epoch - 2ms/step
# Epoch 356/400
# 47/47 - 0s - loss: 483.7806 - 77ms/epoch - 2ms/step
# Epoch 357/400
# 47/47 - 0s - loss: 470.2755 - 78ms/epoch - 2ms/step
# Epoch 358/400
# 47/47 - 0s - loss: 503.4658 - 83ms/epoch - 2ms/step
# Epoch 359/400
# 47/47 - 0s - loss: 519.7378 - 90ms/epoch - 2ms/step
# Epoch 360/400
# 47/47 - 0s - loss: 483.0977 - 91ms/epoch - 2ms/step
# Epoch 361/400
# 47/47 - 0s - loss: 487.1677 - 79ms/epoch - 2ms/step
# Epoch 362/400
# 47/47 - 0s - loss: 495.7936 - 88ms/epoch - 2ms/step
# Epoch 363/400
# 47/47 - 0s - loss: 484.8841 - 80ms/epoch - 2ms/step
# Epoch 364/400
# 47/47 - 0s - loss: 476.7788 - 74ms/epoch - 2ms/step
# Epoch 365/400
# 47/47 - 0s - loss: 508.1829 - 79ms/epoch - 2ms/step
# Epoch 366/400
# 47/47 - 0s - loss: 483.3478 - 77ms/epoch - 2ms/step
# Epoch 367/400
# 47/47 - 0s - loss: 487.6913 - 86ms/epoch - 2ms/step
# Epoch 368/400
# 47/47 - 0s - loss: 475.8810 - 75ms/epoch - 2ms/step
# Epoch 369/400
# 47/47 - 0s - loss: 475.8057 - 76ms/epoch - 2ms/step
# Epoch 370/400
# 47/47 - 0s - loss: 503.7846 - 83ms/epoch - 2ms/step
# Epoch 371/400
# 47/47 - 0s - loss: 463.8649 - 81ms/epoch - 2ms/step
# Epoch 372/400
# 47/47 - 0s - loss: 462.2182 - 88ms/epoch - 2ms/step
# Epoch 373/400
# 47/47 - 0s - loss: 543.4847 - 73ms/epoch - 2ms/step
# Epoch 374/400
# 47/47 - 0s - loss: 490.5859 - 74ms/epoch - 2ms/step
# Epoch 375/400
# 47/47 - 0s - loss: 462.5921 - 81ms/epoch - 2ms/step
# Epoch 376/400
# 47/47 - 0s - loss: 494.5425 - 81ms/epoch - 2ms/step
# Epoch 377/400
# 47/47 - 0s - loss: 474.8130 - 80ms/epoch - 2ms/step
# Epoch 378/400
# 47/47 - 0s - loss: 467.0340 - 73ms/epoch - 2ms/step
# Epoch 379/400
# 47/47 - 0s - loss: 479.7498 - 76ms/epoch - 2ms/step
# Epoch 380/400
# 47/47 - 0s - loss: 490.9819 - 77ms/epoch - 2ms/step
# Epoch 381/400
# 47/47 - 0s - loss: 525.8779 - 85ms/epoch - 2ms/step
# Epoch 382/400
# 47/47 - 0s - loss: 492.9085 - 92ms/epoch - 2ms/step
# Epoch 383/400
# 47/47 - 0s - loss: 480.5456 - 77ms/epoch - 2ms/step
# Epoch 384/400
# 47/47 - 0s - loss: 488.9340 - 79ms/epoch - 2ms/step
# Epoch 385/400
# 47/47 - 0s - loss: 484.1516 - 94ms/epoch - 2ms/step
# Epoch 386/400
# 47/47 - 0s - loss: 454.9399 - 80ms/epoch - 2ms/step
# Epoch 387/400
# 47/47 - 0s - loss: 474.0466 - 80ms/epoch - 2ms/step
# Epoch 388/400
# 47/47 - 0s - loss: 478.9222 - 72ms/epoch - 2ms/step
# Epoch 389/400
# 47/47 - 0s - loss: 486.2950 - 74ms/epoch - 2ms/step
# Epoch 390/400
# 47/47 - 0s - loss: 535.4733 - 85ms/epoch - 2ms/step
# Epoch 391/400
# 47/47 - 0s - loss: 470.7327 - 78ms/epoch - 2ms/step
# Epoch 392/400
# 47/47 - 0s - loss: 470.5499 - 85ms/epoch - 2ms/step
# Epoch 393/400
# 47/47 - 0s - loss: 469.0410 - 78ms/epoch - 2ms/step
# Epoch 394/400
# 47/47 - 0s - loss: 482.0596 - 84ms/epoch - 2ms/step
# Epoch 395/400
# 47/47 - 0s - loss: 485.3591 - 77ms/epoch - 2ms/step
# Epoch 396/400
# 47/47 - 0s - loss: 518.6866 - 77ms/epoch - 2ms/step
# Epoch 397/400
# 47/47 - 0s - loss: 471.8671 - 91ms/epoch - 2ms/step
# Epoch 398/400
# 47/47 - 0s - loss: 465.4961 - 73ms/epoch - 2ms/step
# Epoch 399/400
# 47/47 - 0s - loss: 470.1259 - 83ms/epoch - 2ms/step
# Epoch 400/400
# 47/47 - 0s - loss: 476.4788 - 73ms/epoch - 2ms/step
# Train Score: 453.44 MSE (21.29 RMSE)
# Test Score: 1945.77 MSE (44.11 RMSE)
# 3/3 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step

# %% [markdown]
# Normalise Dataset

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d15a995deba0> in <cell line: 2>()
#       1 # normalize the dataset
# ----> 2 scaler = MinMaxScaler(feature_range=(0, 1))
#       3 dataset = scaler.fit_transform(dataset)
#
# NameError: name 'MinMaxScaler' is not defined

# %% [markdown]
# Reshape the Prepared Dataset for the LSTM Layers

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# Define and Fit the LSTM network

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error' , optimizer= 'adam' )
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# %% [markdown]
# LSTM Model on the t+1 Problem

# %%
# LSTM for international airline passengers problem with regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv( 'international-airline-passengers.csv' , usecols=[1], engine= 'python' )
dataset = dataframe.values
dataset = dataset.astype( 'float32' )
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error' , optimizer= 'adam' )
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print( 'Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print( 'Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# LSTM for the Window Model

# %%
# LSTM for international airline passengers problem with window regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv( 'international-airline-passengers.csv' , usecols=[1], engine= 'python' )
dataset = dataframe.values
dataset = dataset.astype( 'float32' )
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error' , optimizer= 'adam' )
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print( 'Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print( 'Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Reshape the Prepared Dataset for the LSTM Layers with Time Steps

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %% [markdown]
# LSTM for the Time Steps Model

# %%
# LSTM for international airline passengers problem with time step regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv( 'international-airline-passengers.csv' , usecols=[1], engine= 'python' )
dataset = dataframe.values
dataset = dataset.astype( 'float32' )
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error' , optimizer= 'adam' )
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print( 'Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print( 'Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Manually Reset LSTM State Between Epochs.

# %%
for i in range(100):
  model.fit(trainX, trainY, epochs=1, batch_size= batch_size, verbose=2, shuffle=False)
  model.reset_states()

# %% [markdown]
# Set the Stateful Parameter on the LSTM Layer

# %%
model.add(LSTM(4, batch_input_shape=(batch_size, time_steps, features), stateful=True))

# %% [markdown]
# Set Batch Size when making Predictions

# %%
model.predict(trainX, batch_size=batch_size)

# %% [markdown]
# LSTM for the Manual Management of State

# %%
# LSTM for international airline passengers problem with memory
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv( 'international-airline-passengers.csv' , usecols=[1], engine= 'python' )
dataset = dataframe.values
dataset = dataset.astype( 'float32' )
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error' , optimizer= 'adam' )
for i in range(100):
  model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
  model.reset_states()
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print( 'Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print( 'Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# Define a Stacked LSTM Model

# %%
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True,
  return_sequences=True))
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))

# %% [markdown]
# Stacked LSTM Model

# %%
# Stacked LSTM for international airline passengers problem with memory
import numpy
8
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv( 'international-airline-passengers.csv' , usecols=[1], engine= 'python' )
dataset = dataframe.values
dataset = dataset.astype( 'float32' )
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True,
return_sequences=True))
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error' , optimizer= 'adam' )
for i in range(100):
  model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
  model.reset_states()
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print( 'Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print( 'Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
